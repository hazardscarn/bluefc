# %%
import requests
import json
from typing import Dict, List, Optional, Any
from dataclasses import dataclass
from pprint import pprint

# Copy the QlooAPIClient class from the provided implementation
from src.qloo import QlooAPIClient, QlooSignals, QlooAudience

# Initialize client
client = QlooAPIClient(api_key='cNgE_gZAGdR_tdP1HMHkOlr86MGc8C2eaOeqBWQ_3ks')

# Test connection
connection_test = client.test_connection()
print(connection_test)
# Out:
# {'success': True, 'status_code': 200, 'message': 'Connection successful', 'postman_url': 'https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:brand&take=5&signal.location.query=North America', 'headers_needed': {'X-Api-Key': 'YOUR_API_KEY'}}

# %%
# Create signals with entity queries (text-based) - CORRECTED
signals_with_queries = QlooSignals(
    demographics={},
    location={},
    entity_queries=[],  # ✅ This now works!,
    tag_ids=["urn:audience:communities",
"urn:audience:hobbies_and_interests",
"urn:audience:leisure",
"urn:audience:professional_area",
"urn:audience:spending_habits",
"urn:audience:life_stage",
"urn:audience:investing_interests"]
)

print("🔍 Finding audiences with entity queries...")
print(f"Entity Queries: {signals_with_queries.entity_queries}")


result = client.find_audiences(signals=signals_with_queries, limit=200)
print(f"Found {result['total_found']} audiences")  # Should show results now!

print(f"\n📊 Found {result['total_found']} audiences using entity queries:")
for i, audience in enumerate(result['audiences'], 1):
    print(f"{i}. {audience.name} (ID: {audience.id})")
    print(f"   Type: {audience.parent_type}")
    print(f"   Entity ID: {audience.entity_id}")
    print()
# Out:
# 🔍 Finding audiences with entity queries...
# Entity Queries: []
# Found 104 audiences
#
# 📊 Found 104 audiences using entity queries:
# 1. Health And Beauty (ID: urn:audience:hobbies_and_interests:health_and_beauty)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 8F0407D3-64F3-47BF-A6B1-BA4C30465F71
#
# 2. Adventuring (ID: urn:audience:hobbies_and_interests:adventuring)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: DBDCB7B7-B015-425F-9C3E-619C9C4245EB
#
# 3. Photography (ID: urn:audience:hobbies_and_interests:photography)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7DCA3589-E6FF-4582-BE24-5A2D09D71336
#
# 4. Tattoos (ID: urn:audience:hobbies_and_interests:tattoos)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 965CD575-A0AD-4128-88B6-DE0C599D644F
#
# 5. Meditation (ID: urn:audience:hobbies_and_interests:meditation)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1C3735D4-FE2D-4CDE-811A-9B2BFE767DAD
#
# 6. Hockey (ID: urn:audience:hobbies_and_interests:hockey)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1CA32D17-6D03-453C-8B91-12B4604076E1
#
# 7. American Football (ID: urn:audience:hobbies_and_interests:american_football)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 31C1423A-6A88-4028-ADEC-C3042BE765B9
#
# 8. Martial Arts (ID: urn:audience:hobbies_and_interests:martial_arts)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 663BAA0C-44CF-4794-8827-E36FBEF3E5F5
#
# 9. Running (ID: urn:audience:hobbies_and_interests:running)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: EEFA88EB-0D5D-4290-B0AB-F7840DE970DB
#
# 10. Secret Unravelers (ID: urn:audience:hobbies_and_interests:secret_unravelers)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 471BEA15-6E9F-4347-B3DF-46E4A6045B8E
#
# 11. Motorcycles (ID: urn:audience:hobbies_and_interests:motorcycles)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 107AE5DB-906C-430C-969E-3886C39BDD8C
#
# 12. Jewellery (ID: urn:audience:hobbies_and_interests:jewellery)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: ED9B04EF-C693-44C8-82DE-C2B138710601
#
# 13. Hiking (ID: urn:audience:hobbies_and_interests:hiking)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 73B662F7-7DB7-4D0C-A36B-2E8E75ACDF49
#
# 14. Watches (ID: urn:audience:hobbies_and_interests:watches)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 40A2CD3E-0A56-4341-9996-9EF819D39398
#
# 15. Spy Enthusiast (ID: urn:audience:hobbies_and_interests:spy_enthusiast)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 174B1FE8-CDCE-4896-ADF5-E59981B9AE95
#
# 16. Arts Crafts (ID: urn:audience:hobbies_and_interests:arts_crafts)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 604A723B-3E2C-4795-89AA-DF5BA0C3B3C5
#
# 17. Wrestling (ID: urn:audience:hobbies_and_interests:wrestling)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: FE2A1718-8970-46D1-947F-D23B199F906D
#
# 18. Home Organization (ID: urn:audience:hobbies_and_interests:home_organization)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 9130A837-ED3C-4BA9-9825-5D0D57D119CD
#
# 19. Sneakerheads (ID: urn:audience:hobbies_and_interests:sneakerheads)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: D4B24E84-C439-4D7C-B2DC-92F7C704DE76
#
# 20. Travel (ID: urn:audience:hobbies_and_interests:travel)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7CB916B9-1D27-4D76-8D97-2CC5950385CA
#
# 21. Golf (ID: urn:audience:hobbies_and_interests:golf)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 566BE3C4-C712-4B76-916D-2EFC0D26BD81
#
# 22. High Fashion (ID: urn:audience:hobbies_and_interests:high_fashion)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: FA88A1F6-8CEF-4F6A-8FD1-FE7A739052D7
#
# 23. Home Decor (ID: urn:audience:hobbies_and_interests:home_decor)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7F86E72A-AF3C-4AA9-B125-7155E9261466
#
# 24. Street Fashion (ID: urn:audience:hobbies_and_interests:street_fashion)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1F3BBF4D-D14C-4C1D-B9BD-8F8CDCEA55FA
#
# 25. Video Gamer (ID: urn:audience:hobbies_and_interests:video_gamer)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 803132BB-07E8-4D55-A37D-8B9EFB3E095F
#
# 26. Tennis (ID: urn:audience:hobbies_and_interests:tennis)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 689CB6FD-E1A9-4B06-9932-3093B8F61A97
#
# 27. Swimming (ID: urn:audience:hobbies_and_interests:swimming)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7A1AEC8A-06B4-4834-B1E1-FD45648D9BE3
#
# 28. Automotive (ID: urn:audience:hobbies_and_interests:automotive)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: F8369494-BD42-4DA1-A056-2315241E2401
#
# 29. Musician (ID: urn:audience:hobbies_and_interests:musician)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 15D9D8DF-28AF-425A-AF2E-835DFB53E778
#
# 30. Perfume (ID: urn:audience:hobbies_and_interests:perfume)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7010BFFD-33F5-460C-8660-3E49C570FF47
#
# 31. Casual Escapists (ID: urn:audience:hobbies_and_interests:casual_escapists)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: E7EC95B5-91D3-4B36-90CD-868680D13C93
#
# 32. Racing (ID: urn:audience:hobbies_and_interests:racing)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 9D36D8C6-B39C-48AE-87A6-F63E59328577
#
# 33. Adrenaline Rushers (ID: urn:audience:hobbies_and_interests:adrenaline_rushers)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1D7AF41D-8ECF-414C-B6C9-7CA9FA276DBD
#
# 34. Soccer (ID: urn:audience:hobbies_and_interests:soccer)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 8C44B7FB-384C-445D-8FB0-01AD0BB54248
#
# 35. Yoga (ID: urn:audience:hobbies_and_interests:yoga)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: F488B2E4-21FE-4AFA-8B2E-0DA5A0F4E756
#
# 36. Baseball (ID: urn:audience:hobbies_and_interests:baseball)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: E8694D82-FE70-4EA5-A87B-53B90607EA75
#
# 37. Architecture (ID: urn:audience:hobbies_and_interests:architecture)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 67A1B149-175D-4005-85E1-C0A395A1FA4F
#
# 38. Wine Enthusiast (ID: urn:audience:hobbies_and_interests:wine_enthusiast)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 14F62034-5661-4B52-822B-D2D88A3D1B02
#
# 39. Basketball (ID: urn:audience:hobbies_and_interests:basketball)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 53E66B25-2B9E-4821-8257-65F66B62DD80
#
# 40. Outdoors (ID: urn:audience:hobbies_and_interests:outdoors)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: AAAE9FAA-FE3D-4732-9E82-BD4CED485D60
#
# 41. Fishing (ID: urn:audience:hobbies_and_interests:fishing)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 2D160ADC-1673-4D12-9530-D6E78DE07087
#
# 42. Dance (ID: urn:audience:hobbies_and_interests:dance)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1B095F7B-1A06-4F65-AE32-BB9E9EAC26D6
#
# 43. Vintage Apparel (ID: urn:audience:spending_habits:vintage_apparel)
#    Type: urn:audience:spending_habits
#    Entity ID: 7553AEF3-0213-4419-8C17-E4CDF28B2BB0
#
# 44. Technology Enthusiast (ID: urn:audience:spending_habits:technology_enthusiast)
#    Type: urn:audience:spending_habits
#    Entity ID: F9619A04-A80C-4FB8-BBD4-7E653E31075F
#
# 45. Watch Collecting (ID: urn:audience:spending_habits:watch_collecting)
#    Type: urn:audience:spending_habits
#    Entity ID: B966ABDA-92B7-4C91-B598-C65CE6013C9B
#
# 46. Boutique Hotels (ID: urn:audience:spending_habits:boutique_hotels)
#    Type: urn:audience:spending_habits
#    Entity ID: F66B9D4E-1503-4BA1-8ABB-745652CA2A12
#
# 47. Discount Shoppers (ID: urn:audience:spending_habits:discount_shoppers)
#    Type: urn:audience:spending_habits
#    Entity ID: B374F423-E1E6-4783-AA1E-48A6B2B5635F
#
# 48. Gourmand Fine Dining (ID: urn:audience:spending_habits:gourmand_fine_dining)
#    Type: urn:audience:spending_habits
#    Entity ID: ED8798A4-1EB1-4E53-80EA-4FD08BD3C148
#
# 49. AAPI (ID: urn:audience:communities:aapi)
#    Type: urn:audience:communities
#    Entity ID: DA61B8AD-6D79-4B0C-BEA0-EC966C93902E
#
# 50. Latino (ID: urn:audience:communities:latino)
#    Type: urn:audience:communities
#    Entity ID: E47478B9-8ED2-449B-B854-6344059742E3
#
# 51. LGBTQ (ID: urn:audience:communities:lgbtq)
#    Type: urn:audience:communities
#    Entity ID: 6BED625C-E312-47E9-A4B5-F978C7778269
#
# 52. Black (ID: urn:audience:communities:black)
#    Type: urn:audience:communities
#    Entity ID: A8A43978-5291-46DC-8952-D58EDC7FF82B
#
# 53. Climate Activism (ID: urn:audience:global_issues:climate_activism)
#    Type: urn:audience:global_issues
#    Entity ID: FB61D98E-C4BA-4959-A571-0861FD2AC850
#
# 54. Gender Equality (ID: urn:audience:global_issues:gender_equality)
#    Type: urn:audience:global_issues
#    Entity ID: B7970242-69CC-40FB-AFB6-0A5781E613DB
#
# 55. Racial Justice (ID: urn:audience:global_issues:racial_justice)
#    Type: urn:audience:global_issues
#    Entity ID: 9D25E87E-030C-4EE7-B049-F24967AAD596
#
# 56. Education Issues (ID: urn:audience:global_issues:education_issues)
#    Type: urn:audience:global_issues
#    Entity ID: 616F4741-3864-41FD-BFCF-49B76AA025C8
#
# 57. Ocean Health (ID: urn:audience:global_issues:ocean_health)
#    Type: urn:audience:global_issues
#    Entity ID: BAC54F13-A15E-49E8-A645-BCACD5683B14
#
# 58. Foreign Affairs (ID: urn:audience:global_issues:foreign_affairs)
#    Type: urn:audience:global_issues
#    Entity ID: 1EFF8636-B50C-4B57-86DD-6CB2D4F8F397
#
# 59. Wealth Inequality (ID: urn:audience:global_issues:wealth_inequality)
#    Type: urn:audience:global_issues
#    Entity ID: C956BAAF-4449-4B0B-BCA1-D3B06644B165
#
# 60. Animal Issues (ID: urn:audience:global_issues:animal_issues)
#    Type: urn:audience:global_issues
#    Entity ID: 784D31A2-99A5-4E8C-8B89-047B01760CC2
#
# 61. Mental Health (ID: urn:audience:global_issues:mental_health)
#    Type: urn:audience:global_issues
#    Entity ID: B48DAA8A-7398-4C76-9DB0-80E12669ABFD
#
# 62. Sustainability (ID: urn:audience:global_issues:sustainability)
#    Type: urn:audience:global_issues
#    Entity ID: 109574B3-A21D-4935-AC94-1DC3C7B56BEC
#
# 63. Fair Wages (ID: urn:audience:global_issues:fair_wages)
#    Type: urn:audience:global_issues
#    Entity ID: 2EE4FA44-9A90-470F-839F-2CF54A273E59
#
# 64. Stocks Bonds (ID: urn:audience:investing_interests:stocks_bonds)
#    Type: urn:audience:investing_interests
#    Entity ID: 1B2E2B7F-2FF5-495F-9389-FD4D35A03144
#
# 65. Angel Start Up Investing (ID: urn:audience:investing_interests:angel_start_up_investing)
#    Type: urn:audience:investing_interests
#    Entity ID: 2C606C12-C64F-46B1-BAE6-4FB0C278E612
#
# 66. Real Estate (ID: urn:audience:investing_interests:real_estate)
#    Type: urn:audience:investing_interests
#    Entity ID: 2248A93C-17C0-4BCD-A671-19DB6BDB98D3
#
# 67. NFT Collectors (ID: urn:audience:investing_interests:nft_collectors)
#    Type: urn:audience:investing_interests
#    Entity ID: 35DD51F5-4C89-436D-9A36-1C6BDD1D1508
#
# 68. Cryptocurrency Enthusiasts (ID: urn:audience:investing_interests:cryptocurrency_enthusiasts)
#    Type: urn:audience:investing_interests
#    Entity ID: C11DC8FF-5EDC-4B64-9504-1CD64C1B10FA
#
# 69. Art Collectibles (ID: urn:audience:investing_interests:art_collectibles)
#    Type: urn:audience:investing_interests
#    Entity ID: 42D6F3D0-AD4A-4AC8-B3EE-229775638336
#
# 70. Political Junkie (ID: urn:audience:leisure:political_junkie)
#    Type: urn:audience:leisure
#    Entity ID: 539308D1-B0B5-4C9D-8B67-E7B565B59B09
#
# 71. Arts Culture (ID: urn:audience:leisure:arts_culture)
#    Type: urn:audience:leisure
#    Entity ID: AAF408EF-5947-4035-BD34-6678F4A94994
#
# 72. Foodie (ID: urn:audience:leisure:foodie)
#    Type: urn:audience:leisure
#    Entity ID: F86C9FE1-16D1-4CFA-8E33-77AD4FEDBB60
#
# 73. Cooking (ID: urn:audience:leisure:cooking)
#    Type: urn:audience:leisure
#    Entity ID: D1F0EE4A-FDB3-48DC-919C-5A94F3D4EC85
#
# 74. Museums (ID: urn:audience:leisure:museums)
#    Type: urn:audience:leisure
#    Entity ID: 8371AF94-2F4C-4139-BC87-E3FBEA695D88
#
# 75. Cinephile (ID: urn:audience:leisure:cinephile)
#    Type: urn:audience:leisure
#    Entity ID: AB40A444-E528-43FE-BE78-E014301CFD80
#
# 76. Music Festivals (ID: urn:audience:leisure:music_festivals)
#    Type: urn:audience:leisure
#    Entity ID: 61D4EAAB-8591-4CCC-BEFC-5F0D18C4F3BD
#
# 77. Avid Reader (ID: urn:audience:leisure:avid_reader)
#    Type: urn:audience:leisure
#    Entity ID: 2EFF1AB9-814F-48D2-B2DE-D418ED8385AE
#
# 78. Exercising (ID: urn:audience:leisure:exercising)
#    Type: urn:audience:leisure
#    Entity ID: E1C2F640-4C29-4F79-AD75-82CDE3DB4622
#
# 79. Coffee (ID: urn:audience:leisure:coffee)
#    Type: urn:audience:leisure
#    Entity ID: AFA24856-F432-40E3-AADF-C939A033F77E
#
# 80. News Junkie (ID: urn:audience:leisure:news_junkie)
#    Type: urn:audience:leisure
#    Entity ID: 3A9990DA-AA86-4934-AC8D-4088E91700AA
#
# 81. Parents With Young Children (ID: urn:audience:life_stage:parents_with_young_children)
#    Type: urn:audience:life_stage
#    Entity ID: 22D0A7AF-7833-49F3-8E36-42E8D91EEC8B
#
# 82. Engaged (ID: urn:audience:life_stage:engaged)
#    Type: urn:audience:life_stage
#    Entity ID: DBF3D836-74E1-4A50-BAF7-6F3426ADA64A
#
# 83. Single (ID: urn:audience:life_stage:single)
#    Type: urn:audience:life_stage
#    Entity ID: 61419C52-AA82-48FB-A68E-F873A417E040
#
# 84. Retirement (ID: urn:audience:life_stage:retirement)
#    Type: urn:audience:life_stage
#    Entity ID: B88B7B93-BD33-4910-B44E-24B06C6C8164
#
# 85. Astrology (ID: urn:audience:lifestyle_preferences_beliefs:astrology)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 5F4CF648-08CD-4031-A17E-491E90A4DD4C
#
# 86. Organic Ingredients (ID: urn:audience:lifestyle_preferences_beliefs:organic_ingredients)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: D3839B31-2A5F-4DA3-8C04-528D9611039E
#
# 87. Christianity (ID: urn:audience:lifestyle_preferences_beliefs:christianity)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 2A7B1369-BF0D-46E2-AAEE-780817162FF4
#
# 88. Healthy Eating (ID: urn:audience:lifestyle_preferences_beliefs:healthy_eating)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: F854077D-E466-4181-A7E4-4CDA52981EA2
#
# 89. Judaism (ID: urn:audience:lifestyle_preferences_beliefs:judaism)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 399883E7-F468-4BD6-9209-91DAD7BF3537
#
# 90. Veganism (ID: urn:audience:lifestyle_preferences_beliefs:veganism)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 7819CC7E-FEAF-4FC6-B0D8-EFED92CD46AE
#
# 91. Spirituality (ID: urn:audience:lifestyle_preferences_beliefs:spirituality)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 439B29E4-F9B2-4FA7-8095-123F6833DE5F
#
# 92. Islam (ID: urn:audience:lifestyle_preferences_beliefs:islam)
#    Type: urn:audience:lifestyle_preferences_beliefs
#    Entity ID: 87A86EE9-5CA0-4C1F-8237-E3EE73C72281
#
# 93. Politically Progressive (ID: urn:audience:political_preferences:politically_progressive)
#    Type: urn:audience:political_preferences
#    Entity ID: B3A035FD-0D99-4980-98FD-A5B81D7E402A
#
# 94. Politically Center (ID: urn:audience:political_preferences:politically_center)
#    Type: urn:audience:political_preferences
#    Entity ID: A2F107FD-2A38-4100-AFFB-037A6A2DF338
#
# 95. Politically Conservative (ID: urn:audience:political_preferences:politically_conservative)
#    Type: urn:audience:political_preferences
#    Entity ID: 555258C9-2696-496A-B1C1-C46A6F7795C8
#
# 96. Business Professional (ID: urn:audience:professional_area:business_professional)
#    Type: urn:audience:professional_area
#    Entity ID: A6230919-E0C8-4707-89E5-F7C5BCE86A70
#
# 97. Hospitality Professional (ID: urn:audience:professional_area:hospitality_professional)
#    Type: urn:audience:professional_area
#    Entity ID: 20561289-536A-41EE-A841-23A6ED3D583B
#
# 98. Medical Professional (ID: urn:audience:professional_area:medical_professional)
#    Type: urn:audience:professional_area
#    Entity ID: 7A247E73-7190-4340-8EAD-227EEFB22780
#
# 99. Advertising Design (ID: urn:audience:professional_area:advertising_design)
#    Type: urn:audience:professional_area
#    Entity ID: 6CE667C5-82C8-44EC-8E23-01AF8F9949D1
#
# 100. Technology Professional (ID: urn:audience:professional_area:technology_professional)
#    Type: urn:audience:professional_area
#    Entity ID: F81DBC4E-5DB2-43B5-9456-B1409FCF1441
#
# 101. Marketing Professional (ID: urn:audience:professional_area:marketing_professional)
#    Type: urn:audience:professional_area
#    Entity ID: 98C407BC-7949-4440-A933-451853D966E4
#
# 102. Retail Professional (ID: urn:audience:professional_area:retail_professional)
#    Type: urn:audience:professional_area
#    Entity ID: 7D3C0540-10B0-42BB-93BE-676F0C37242F
#
# 103. Finance Professional (ID: urn:audience:professional_area:finance_professional)
#    Type: urn:audience:professional_area
#    Entity ID: 0E757BF5-3C77-41AF-AAB7-790AEB0505B7
#
# 104. Sales Professional (ID: urn:audience:professional_area:sales_professional)
#    Type: urn:audience:professional_area
#    Entity ID: EFCD3505-3119-4BBD-86D0-0B9F344C0C94

# %%
qloo_signals = QlooSignals(
    demographics={"age": "24_and_younger,25_to_29,30_to_34,35_to_44"},
    location={"query": "Los Angeles"},
    audience_ids=[
        "urn:audience:hobbies_and_interests:american_football",
        "urn:audience:hobbies_and_interests:soccer", 
        "urn:audience:life_stage:parents_with_young_children"
    ]
)
insights = client.get_entity_insights(
    audience_ids=[],  # Let signals handle audiences
    entity_type="brand", 
    signals=qloo_signals,
    limit=10
)
insights
# Out:
# {'success': True,
#  'entity_type': 'brand',
#  'audience_ids': [],
#  'request_method': 'GET',
#  'params_used': {'filter.type': 'urn:entity:brand',
#   'take': '10',
#   'signal.demographics.age': '24_and_younger,25_to_29,30_to_34,35_to_44',
#   'signal.location.query': 'Los Angeles',
#   'signal.demographics.audiences': 'urn:audience:hobbies_and_interests:american_football,urn:audience:hobbies_and_interests:soccer,urn:audience:life_stage:parents_with_young_children'},
#  'results': {'entities': [{'name': 'Capital One Platinum Credit Card',
#     'entity_id': 'C2953021-674F-4EB4-ACCD-5AC475D99E09',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/C2953021-674F-4EB4-ACCD-5AC475D99E09-420x-auto.jpg'},
#      'short_description': 'Capital One Platinum Credit Card is a no-annual-fee Mastercard designed to help build or rebuild credit, with automatic credit line reviews.'},
#     'popularity': 0.8475530165618484,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9728468473993558,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Citi Simplicity Card',
#     'entity_id': '02834D1D-D6C8-42ED-8C50-CDDEE76AA5A6',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/02834D1D-D6C8-42ED-8C50-CDDEE76AA5A6-420x-auto.jpg'},
#      'short_description': 'The Citi Simplicity Card is a Mastercard credit card offering low introductory APR, no late fees, and no penalty rates for cardmembers.'},
#     'popularity': 0.8949246495228086,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9715932402867526,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Wells Fargo Autograph Card',
#     'entity_id': '2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A-420x-auto.jpg'},
#      'short_description': 'Wells Fargo Autograph Card is a Visa rewards credit card offering 3X points on top spending categories, no annual fee, and exclusive event access.'},
#     'popularity': 0.9805139767083114,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9702188360616933,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Citi Rewards+ Card',
#     'entity_id': 'C629B273-F114-42EA-898F-1FAF287B9C5E',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/C629B273-F114-42EA-898F-1FAF287B9C5E-420x-auto.jpg'},
#      'short_description': 'The Citi Rewards+ Card is a no-annual-fee credit card that earns ThankYou points, rounding up rewards to the nearest 10 points on every purchase.'},
#     'popularity': 0.8153701412079809,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9683756642868784,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Bank of America Premium Rewards Credit Card',
#     'entity_id': 'A27B8B09-4E89-45DB-A912-E268F9C52BE9',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/A27B8B09-4E89-45DB-A912-E268F9C52BE9-420x-auto.jpg'},
#      'short_description': 'A Bank of America credit card offering rewards points on travel, dining, and other purchases with a $95 annual fee.'},
#     'popularity': 0.9004678679798613,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9680661622606431,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Chase Freedom Unlimited',
#     'entity_id': '237A4856-C1D1-4C39-BA16-257517D6FD86',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/237A4856-C1D1-4C39-BA16-257517D6FD86-420x-auto.jpg'},
#      'short_description': 'Chase Freedom Unlimited is a Chase credit card offering unlimited 1.5% cash back on all purchases, with higher rewards on dining, drugstores, and travel booked through Chase Travel.'},
#     'popularity': 0.7055822074553746,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9673340272872438,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Citi Premier Card',
#     'entity_id': '3D580433-EFC8-477C-8DD6-69E2D2BE4840',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/3D580433-EFC8-477C-8DD6-69E2D2BE4840-420x-auto.jpg'},
#      'short_description': 'The Citi Premier Card is a travel rewards credit card offering bonus points on travel, dining, and everyday purchases, with enhanced travel benefits and protections.'},
#     'popularity': 0.8156244172839925,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9666708471421662,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Citi Prestige Credit Card',
#     'entity_id': '40B307A7-9A79-4485-8324-A240FB1DB097',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/40B307A7-9A79-4485-8324-A240FB1DB097-420x-auto.jpg'},
#      'short_description': 'The Citi Prestige Credit Card is a premium travel rewards credit card offering high reward points, travel benefits, and exclusive privileges.'},
#     'popularity': 0.8962214575104677,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9665098131959264,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Capital One Venture Rewards Credit Card',
#     'entity_id': '1EC3AA53-9BB1-4B86-ACB9-E618D6CAA9E2',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/1EC3AA53-9BB1-4B86-ACB9-E618D6CAA9E2-420x-auto.jpg'},
#      'short_description': "A Capital One credit card offering travel rewards with miles that don't expire and a $250 travel credit in the first year."},
#     'popularity': 0.8612330694512722,
#     'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#       'name': 'Financial Services',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#       'name': 'Credit Card',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.966477890026207,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {}},
#    {'name': 'Genius',
#     'entity_id': '4C2CD4FB-C29E-44C1-853F-1D2CFB2AFB4A',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:brand',
#     'properties': {'image': {'url': 'https://images.qloo.com/i/4C2CD4FB-C29E-44C1-853F-1D2CFB2AFB4A-420x-auto.jpg'},
#      'akas': [{'value': 'Genius Media Group Inc.', 'languages': ['es', 'en']},
#       {'value': 'Джиніус', 'languages': ['uk']},
#       {'value': 'جینیس', 'languages': ['fa']},
#       {'value': 'العبقري', 'languages': ['ar']},
#       {'value': 'Джениус', 'languages': ['ru']},
#       {'value': 'জিনিয়াস', 'languages': ['bn']},
#       {'value': 'Genius.com', 'languages': ['es', 'uk', 'en']},
#       {'value': 'دجينيوس (سيت ويب)', 'languages': ['ary']},
#       {'value': 'Rap Genius',
#        'languages': ['fy',
#         'de',
#         'af',
#         'es',
#         'pms',
#         'lb',
#         'et',
#         'ar',
#         'nn',
#         'sh',
#         'pl',
#         'an',
#         'he',
#         'sq',
#         'li',
#         'da',
#         'nl',
#         'nap',
#         'bar',
#         'ru',
#         'eu',
#         'gl',
#         'co',
#         'ca',
#         'sk',
#         'frr',
#         'en',
#         'nds',
#         'tr',
#         'nb',
#         'sv',
#         'wa',
#         'vls',
#         'oc',
#         'lmo',
#         'ast',
#         'uk',
#         'gsw',
#         'bs',
#         'fa',
#         'hr',
#         'uz',
#         'cs',
#         'vec',
#         'id',
#         'vi',
#         'sc',
#         'stq',
#         'ksh',
#         'zh',
#         'fr',
#         'lt',
#         'pfl',
#         'it',
#         'is',
#         'eml',
#         'lv',
#         'fo',
#         'pt',
#         'scn',
#         'ro',
#         'ms',
#         'bn',
#         'zea',
#         'fi',
#         'sl',
#         'sco',
#         'hu']}],
#      'short_descriptions': [{'value': 'Genius descifra textos com anotações linha por linha, adicionadas e editadas por qualquer pessoa no mundo. É o seu guia interativo para a música. Genius tem letras de música anotadas com significado, contexto e interpretações.',
#        'languages': ['pt-br', 'pt']},
#       {'value': 'вэб-бачына мэдыяанатацыяў ЗША',
#        'languages': ['be', 'be-tarask']},
#       {'value': 'американський вебсайт', 'languages': ['uk']},
#       {'value': 'sito web', 'languages': ['it']},
#       {'value': 'American digital media company', 'languages': ['en']},
#       {'value': 'Online-Wissensdatenbank', 'languages': ['de']},
#       {'value': 'website', 'languages': ['nl']},
#       {'value': 'מאגר מידע מוזיקלי-גלובלי מקוון וחופשי', 'languages': ['he']},
#       {'value': '媒體註釋網站', 'languages': ['zh']},
#       {'value': 'американский сайт аннотаций и текстов песен',
#        'languages': ['ru']},
#       {'value': 'site web américain', 'languages': ['fr']},
#       {'value': 'sítio de anotações a ficheiros de mídia',
#        'languages': ['pt']},
#       {'value': 'empresa estadounidense', 'languages': ['es']},
#       {'value': 'webbplats', 'languages': ['sv']}],
#      'short_description': "Genius is a platform hosting the world's largest collection of song lyrics and musical knowledge, powered by a community of contributors."},
#     'popularity': 0.9961519553830245,
#     'tags': [{'id': 'urn:tag:genre:brand:entertainment',
#       'name': 'Entertainment',
#       'type': 'urn:tag:genre:brand'},
#      {'id': 'urn:tag:genre:brand:website',
#       'name': 'Website',
#       'type': 'urn:tag:genre:brand'}],
#     'query': {'affinity': 0.9619931017456792,
#      'measurements': {'audience_growth': 0}},
#     'disambiguation': '',
#     'external': {'instagram': [{'id': 'genius'},
#       {'id': 'geniusisra'},
#       {'id': 'geniu.s'}],
#      'wikidata': [{'id': 'Q3419343'}],
#      'twitter': [{'id': 'genius'}]}}]},
#  'raw_response': {'success': True,
#   'results': {'entities': [{'name': 'Capital One Platinum Credit Card',
#      'entity_id': 'C2953021-674F-4EB4-ACCD-5AC475D99E09',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/C2953021-674F-4EB4-ACCD-5AC475D99E09-420x-auto.jpg'},
#       'short_description': 'Capital One Platinum Credit Card is a no-annual-fee Mastercard designed to help build or rebuild credit, with automatic credit line reviews.'},
#      'popularity': 0.8475530165618484,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9728468473993558,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Citi Simplicity Card',
#      'entity_id': '02834D1D-D6C8-42ED-8C50-CDDEE76AA5A6',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/02834D1D-D6C8-42ED-8C50-CDDEE76AA5A6-420x-auto.jpg'},
#       'short_description': 'The Citi Simplicity Card is a Mastercard credit card offering low introductory APR, no late fees, and no penalty rates for cardmembers.'},
#      'popularity': 0.8949246495228086,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9715932402867526,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Wells Fargo Autograph Card',
#      'entity_id': '2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A-420x-auto.jpg'},
#       'short_description': 'Wells Fargo Autograph Card is a Visa rewards credit card offering 3X points on top spending categories, no annual fee, and exclusive event access.'},
#      'popularity': 0.9805139767083114,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9702188360616933,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Citi Rewards+ Card',
#      'entity_id': 'C629B273-F114-42EA-898F-1FAF287B9C5E',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/C629B273-F114-42EA-898F-1FAF287B9C5E-420x-auto.jpg'},
#       'short_description': 'The Citi Rewards+ Card is a no-annual-fee credit card that earns ThankYou points, rounding up rewards to the nearest 10 points on every purchase.'},
#      'popularity': 0.8153701412079809,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9683756642868784,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Bank of America Premium Rewards Credit Card',
#      'entity_id': 'A27B8B09-4E89-45DB-A912-E268F9C52BE9',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/A27B8B09-4E89-45DB-A912-E268F9C52BE9-420x-auto.jpg'},
#       'short_description': 'A Bank of America credit card offering rewards points on travel, dining, and other purchases with a $95 annual fee.'},
#      'popularity': 0.9004678679798613,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9680661622606431,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Chase Freedom Unlimited',
#      'entity_id': '237A4856-C1D1-4C39-BA16-257517D6FD86',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/237A4856-C1D1-4C39-BA16-257517D6FD86-420x-auto.jpg'},
#       'short_description': 'Chase Freedom Unlimited is a Chase credit card offering unlimited 1.5% cash back on all purchases, with higher rewards on dining, drugstores, and travel booked through Chase Travel.'},
#      'popularity': 0.7055822074553746,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9673340272872438,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Citi Premier Card',
#      'entity_id': '3D580433-EFC8-477C-8DD6-69E2D2BE4840',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/3D580433-EFC8-477C-8DD6-69E2D2BE4840-420x-auto.jpg'},
#       'short_description': 'The Citi Premier Card is a travel rewards credit card offering bonus points on travel, dining, and everyday purchases, with enhanced travel benefits and protections.'},
#      'popularity': 0.8156244172839925,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9666708471421662,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Citi Prestige Credit Card',
#      'entity_id': '40B307A7-9A79-4485-8324-A240FB1DB097',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/40B307A7-9A79-4485-8324-A240FB1DB097-420x-auto.jpg'},
#       'short_description': 'The Citi Prestige Credit Card is a premium travel rewards credit card offering high reward points, travel benefits, and exclusive privileges.'},
#      'popularity': 0.8962214575104677,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9665098131959264,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Capital One Venture Rewards Credit Card',
#      'entity_id': '1EC3AA53-9BB1-4B86-ACB9-E618D6CAA9E2',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/1EC3AA53-9BB1-4B86-ACB9-E618D6CAA9E2-420x-auto.jpg'},
#       'short_description': "A Capital One credit card offering travel rewards with miles that don't expire and a $250 travel credit in the first year."},
#      'popularity': 0.8612330694512722,
#      'tags': [{'id': 'urn:tag:genre:brand:financial_services',
#        'name': 'Financial Services',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:financial_services:credit_card',
#        'name': 'Credit Card',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.966477890026207,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {}},
#     {'name': 'Genius',
#      'entity_id': '4C2CD4FB-C29E-44C1-853F-1D2CFB2AFB4A',
#      'type': 'urn:entity',
#      'subtype': 'urn:entity:brand',
#      'properties': {'image': {'url': 'https://images.qloo.com/i/4C2CD4FB-C29E-44C1-853F-1D2CFB2AFB4A-420x-auto.jpg'},
#       'akas': [{'value': 'Genius Media Group Inc.', 'languages': ['es', 'en']},
#        {'value': 'Джиніус', 'languages': ['uk']},
#        {'value': 'جینیس', 'languages': ['fa']},
#        {'value': 'العبقري', 'languages': ['ar']},
#        {'value': 'Джениус', 'languages': ['ru']},
#        {'value': 'জিনিয়াস', 'languages': ['bn']},
#        {'value': 'Genius.com', 'languages': ['es', 'uk', 'en']},
#        {'value': 'دجينيوس (سيت ويب)', 'languages': ['ary']},
#        {'value': 'Rap Genius',
#         'languages': ['fy',
#          'de',
#          'af',
#          'es',
#          'pms',
#          'lb',
#          'et',
#          'ar',
#          'nn',
#          'sh',
#          'pl',
#          'an',
#          'he',
#          'sq',
#          'li',
#          'da',
#          'nl',
#          'nap',
#          'bar',
#          'ru',
#          'eu',
#          'gl',
#          'co',
#          'ca',
#          'sk',
#          'frr',
#          'en',
#          'nds',
#          'tr',
#          'nb',
#          'sv',
#          'wa',
#          'vls',
#          'oc',
#          'lmo',
#          'ast',
#          'uk',
#          'gsw',
#          'bs',
#          'fa',
#          'hr',
#          'uz',
#          'cs',
#          'vec',
#          'id',
#          'vi',
#          'sc',
#          'stq',
#          'ksh',
#          'zh',
#          'fr',
#          'lt',
#          'pfl',
#          'it',
#          'is',
#          'eml',
#          'lv',
#          'fo',
#          'pt',
#          'scn',
#          'ro',
#          'ms',
#          'bn',
#          'zea',
#          'fi',
#          'sl',
#          'sco',
#          'hu']}],
#       'short_descriptions': [{'value': 'Genius descifra textos com anotações linha por linha, adicionadas e editadas por qualquer pessoa no mundo. É o seu guia interativo para a música. Genius tem letras de música anotadas com significado, contexto e interpretações.',
#         'languages': ['pt-br', 'pt']},
#        {'value': 'вэб-бачына мэдыяанатацыяў ЗША',
#         'languages': ['be', 'be-tarask']},
#        {'value': 'американський вебсайт', 'languages': ['uk']},
#        {'value': 'sito web', 'languages': ['it']},
#        {'value': 'American digital media company', 'languages': ['en']},
#        {'value': 'Online-Wissensdatenbank', 'languages': ['de']},
#        {'value': 'website', 'languages': ['nl']},
#        {'value': 'מאגר מידע מוזיקלי-גלובלי מקוון וחופשי', 'languages': ['he']},
#        {'value': '媒體註釋網站', 'languages': ['zh']},
#        {'value': 'американский сайт аннотаций и текстов песен',
#         'languages': ['ru']},
#        {'value': 'site web américain', 'languages': ['fr']},
#        {'value': 'sítio de anotações a ficheiros de mídia',
#         'languages': ['pt']},
#        {'value': 'empresa estadounidense', 'languages': ['es']},
#        {'value': 'webbplats', 'languages': ['sv']}],
#       'short_description': "Genius is a platform hosting the world's largest collection of song lyrics and musical knowledge, powered by a community of contributors."},
#      'popularity': 0.9961519553830245,
#      'tags': [{'id': 'urn:tag:genre:brand:entertainment',
#        'name': 'Entertainment',
#        'type': 'urn:tag:genre:brand'},
#       {'id': 'urn:tag:genre:brand:website',
#        'name': 'Website',
#        'type': 'urn:tag:genre:brand'}],
#      'query': {'affinity': 0.9619931017456792,
#       'measurements': {'audience_growth': 0}},
#      'disambiguation': '',
#      'external': {'instagram': [{'id': 'genius'},
#        {'id': 'geniusisra'},
#        {'id': 'geniu.s'}],
#       'wikidata': [{'id': 'Q3419343'}],
#       'twitter': [{'id': 'genius'}]}}]},
#   'query': {'localities': {'signal': {'entity_id': '10F17338-97FE-40A3-9434-F6D59F000A9E',
#      'name': 'Los Angeles',
#      'subtype': 'urn:entity:locality',
#      'location': {'lat': 34.19817790176667, 'lon': -118.26109608643324},
#      'popularity': 1,
#      'disambiguation': 'Los Angeles, California, United States of America'}}},
#   'duration': 1102},
#  'postman_url': 'https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:brand&take=10&signal.demographics.age=24_and_younger,25_to_29,30_to_34,35_to_44&signal.location.query=Los Angeles&signal.demographics.audiences=urn:audience:hobbies_and_interests:american_football,urn:audience:hobbies_and_interests:soccer,urn:audience:life_stage:parents_with_young_children',
#  'headers_needed': {'X-Api-Key': 'YOUR_API_KEY'}}

# %% [markdown]
# Entity Search

# %%
# Create a QlooSignals object with the entity as interest
entity_signals = QlooSignals(
    demographics=None,
    location=None,
    entity_ids=['409A342A-B498-4BD4-8BAE-F22FBCD8B196','08A86F7B-4433-4B2B-AA48-A130A725CC92'],  # This is the correct field for signal.interests.entities
    entity_queries=None,
    tag_ids=None
)
entity_signals
# Out:
# QlooSignals(demographics=None, location=None, entity_ids=['409A342A-B498-4BD4-8BAE-F22FBCD8B196', '08A86F7B-4433-4B2B-AA48-A130A725CC92'], entity_queries=None, tag_ids=None)

# %%
all_entity_details = {}
result = client.search_entities(
                query="Republican Party New York",
                limit=2  # Get top 1 per query for better matching
            )
if result['success'] and result['entities']:
                # Take the top result that's most likely a brand
                for entity in result['entities']:
                    if entity.entity_type.lower() in ['brand', 'company', 'product']:
                        all_entity_details[entity.id] = {
                            'name': entity.name,
                            'type': entity.entity_type,
                            'type_urn': entity.type_urn,
                            'popularity': entity.popularity,
                            'query': "Chelsea FC",
                            'entity_id': entity.id
                        }
                        print(f"✅ [TOOL] get_entity_ids_with_context: Found brand - {entity.name} (ID: {entity.id})")

# %%
result
# Out:
# {'success': True,
#  'query': 'Republican Party New York',
#  'entity_types_searched': 'all',
#  'entities': [QlooEntity(id='37B82909-FFFC-4C48-B018-D63715203903', name='Republican Party New York (state) State Senators', entity_type='unknown', type_urn='urn:tag', affinity_score=None, popularity=0.9915887883372043, additional_info={'types': ['urn:tag', 'urn:tag:wikipedia_category:wikidata'], 'properties': {}, 'tags': []}),
#   QlooEntity(id='1D89D571-69FD-4EBE-A77D-D892BF4808A9', name='Republican Party Members Of The New York State Assembly', entity_type='unknown', type_urn='urn:tag', affinity_score=None, popularity=0.9939526592080293, additional_info={'types': ['urn:tag', 'urn:tag:wikipedia_category:wikidata'], 'properties': {}, 'tags': []})],
#  'total_found': 2,
#  'signals_used': {'demographics': None, 'location': None},
#  'params_used': {'query': 'Republican Party New York',
#   'take': '2',
#   'sort_by': 'match'},
#  'raw_response': {'results': [{'name': 'Republican Party New York (state) State Senators',
#     'entity_id': '37B82909-FFFC-4C48-B018-D63715203903',
#     'types': ['urn:tag', 'urn:tag:wikipedia_category:wikidata'],
#     'properties': {},
#     'popularity': 0.9915887883372043,
#     'tags': []},
#    {'name': 'Republican Party Members Of The New York State Assembly',
#     'entity_id': '1D89D571-69FD-4EBE-A77D-D892BF4808A9',
#     'types': ['urn:tag', 'urn:tag:wikipedia_category:wikidata'],
#     'properties': {},
#     'popularity': 0.9939526592080293,
#     'tags': []}]},
#  'postman_url': 'https://hackathon.api.qloo.com/search?query=Republican Party New York&take=2&sort_by=match',
#  'headers_needed': {'X-Api-Key': 'YOUR_API_KEY'}}

# %%
category="movie"
entity_id = '409A342A-B498-4BD4-8BAE-F22FBCD8B196'  # Example entity ID
result = client.get_entity_insights(
    audience_ids=[],
    entity_type=category,
    signals=entity_signals,  # The entity ID is now properly embedded as a signal
    limit=10
)
insight_results= []

if result.get('success') and result.get('results', {}).get('entities'):
                    entities = result['results']['entities']
                    
                    category_insights = [f"\n=== {category.upper()} INSIGHTS FOR ENTITY {entity_id} ==="]
                    
                    for entity in entities[:5]:  # Top 5 per category
                        name = entity.get('name', 'Unknown')
                        affinity = entity.get('query', {}).get('affinity', 0)
                        popularity = entity.get('popularity', 0)
                        description = entity.get('properties', {}).get('short_description', 'No description')[:150]
                        
                        category_insights.append(f"- {name} (Affinity: {affinity:.3f}, Popularity: {popularity:.3f})")
                        if description and description != 'No description':
                            category_insights.append(f"  {description}")
                    
                    insight_results.append("\n".join(category_insights))
print("\n".join(insight_results))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       1 category="movie"
#       2 entity_id = '409A342A-B498-4BD4-8BAE-F22FBCD8B196'  # Example entity ID
#       3 result = client.get_entity_insights(
#       4     audience_ids=[],
#       5     entity_type=category,
# ----> 6     signals=entity_signals,  # The entity ID is now properly embedded as a signal
#       7     limit=10
#       8 )
#       9 insight_results= []
#      11 if result.get('success') and result.get('results', {}).get('entities'):
#
# NameError: name 'entity_signals' is not defined

# %%
signals = QlooSignals(
    demographics={"age": "25_to_29", "gender": "female"},
    location={"query": "New York City"}
)

def get_entity_ids(queries: List[str]):
    """
    Get entity IDs for a list of queries.
    
    Args:
        queries (List[str]): List of entity queries to search for.
        
    Returns:
        List[str]: List of found entity IDs.
    """

    all_entity_ids = []
    entity_details = {}

    print("🔍 Searching for entities to get IDs...")
    for query in queries:
        print(f"\n📍 Searching: '{query}'")
        
        result = client.search_entities(
            query=query,
            limit=2 # Just get top 2 per query
        )
        
        if result['success'] and result['entities']:
            entity = result['entities'][0]  # Take the top result
            all_entity_ids.append(entity.id)
            entity_details[entity.id] = {
                'name': entity.name,
                'type': entity.entity_type,
                'type_urn': entity.type_urn,
                'popularity': entity.popularity,
                'query': query
            }
    return entity_details

# %%
# =============================================================================
# STEP 1: Find Entity IDs with Fixed Type Detection
# =============================================================================
print("=" * 80)
print("STEP 1: Entity Search with Fixed Type Detection")
print("=" * 80)

signals = QlooSignals(
    demographics={"age": "25_to_29", "gender": "female"},
    location={"query": "New York City"}
)

# Test multiple entities to get a good set of entity IDs
test_queries = ["Donald Trump","MAGA"]
all_entity_ids = []
entity_details = {}

print("🔍 Searching for entities to get IDs...")
for query in test_queries:
    print(f"\n📍 Searching: '{query}'")
    
    result = client.search_entities(
        query=query,
        signals=signals,
        limit=2 # Just get top 2 per query
    )
    
    if result['success'] and result['entities']:
        entity = result['entities'][0]  # Take the top result
        all_entity_ids.append(entity.id)
        entity_details[entity.id] = {
            'name': entity.name,
            'type': entity.entity_type,
            'type_urn': entity.type_urn,
            'popularity': entity.popularity,
            'query': query
        }
        
        print(f"  ✅ {entity.name}")
        print(f"     Type: {entity.entity_type} (URN: {entity.type_urn})")
        print(f"     ID: {entity.id}")
        print(f"     Popularity: {entity.popularity:.3f}")
    else:
        print(f"  ❌ No results for '{query}'")

print(f"\n🎯 Collected {len(all_entity_ids)} entity IDs for insights testing")
print()

# =============================================================================
# STEP 2: Direct Entity IDs → Movie Insights (Detailed Analysis)
# =============================================================================
print("=" * 80)
print("STEP 2: Direct Entity IDs → Movie Insights (Detailed)")
print("=" * 80)


print(f"🎬 Getting movie insights using {len(all_entity_ids)} entity IDs...")
print(f"Entity IDs: {all_entity_ids[:3]}..." if len(all_entity_ids) > 3 else f"Entity IDs: {all_entity_ids}")

# Create signals with entity IDs (no audiences needed!)
entity_signals = QlooSignals(
    demographics={"age": "25_to_29", "gender": "female"},
    location={"query": "New York City"},
    entity_ids=all_entity_ids  # Direct entity-based insights
)

# Method 1: Try with empty audience_ids (might work)
print("\n🔄 Method 1: Empty audiences + entity signals...")
movie_insights = client.get_entity_insights(
    audience_ids=[],  # Empty - we're using entity signals instead
    entity_type="movie",
    signals=entity_signals,
    limit=10
)

def display_movie_insights(entity):
    """Display comprehensive movie information"""
    print(f"🎬 MOVIE: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Release information
    if 'release_year' in props:
        print(f"   📅 Release Year: {props['release_year']}")
    if 'release_date' in props:
        print(f"   📅 Release Date: {props['release_date']}")
    
    # Duration
    if 'duration' in props:
        print(f"   ⏱️ Duration: {props['duration']} minutes")
    
    # Rating
    if 'content_rating' in props:
        print(f"   🎭 Content Rating: {props['content_rating']}")
    
    # Description
    if 'description' in props:
        description = props['description'][:200] + "..." if len(props['description']) > 200 else props['description']
        print(f"   📝 Plot: {description}")
    
    # Production details
    if 'production_companies' in props and props['production_companies']:
        companies = props['production_companies'][:3]
        print(f"   🎭 Production: {', '.join(companies)}")
    
    # Filming location
    if 'filming_location' in props:
        print(f"   🎥 Filmed in: {props['filming_location']}")
    
    # Release countries
    if 'release_country' in props and props['release_country']:
        countries = props['release_country'][:3]
        print(f"   🌍 Released in: {', '.join(countries)}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    # Websites
    if 'websites' in props and props['websites']:
        print(f"   🌐 Official Site: {props['websites'][0]}")
    

    postman_url = movie_insights.get('postman_url', 'N/A')
        
    print(f"\n🔗 Postman URL: {postman_url}")
    print("   " + "="*60)



"""Display all movie insights"""
if movie_insights['success'] and movie_insights['results'].get('entities'):
    entities = movie_insights['results']['entities']
    print(f"\n🎬 MOVIE INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_movie_insights(entity)
else:
    print(f"\n❌ MOVIES: FAILED - {movie_insights.get('error', 'Unknown error')}")
# Out:
# ================================================================================
# STEP 1: Entity Search with Fixed Type Detection
# ================================================================================
# 🔍 Searching for entities to get IDs...
#
# 📍 Searching: 'Donald Trump'
#   ✅ Donald Trump
#      Type: people (URN: urn:entity:person)
#      ID: A753C115-8A82-46B7-8847-0FECC62C4DBD
#      Popularity: 0.999
#
# 📍 Searching: 'MAGA'
#   ✅ Maga
#      Type: album (URN: urn:entity:album)
#      ID: DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#      Popularity: 0.979
#
# 🎯 Collected 2 entity IDs for insights testing
#
# ================================================================================
# STEP 2: Direct Entity IDs → Movie Insights (Detailed)
# ================================================================================
# 🎬 Getting movie insights using 2 entity IDs...
# Entity IDs: ['A753C115-8A82-46B7-8847-0FECC62C4DBD', 'DFFF5B0D-54C8-42D9-96C2-03193CD571C1']
#
# 🔄 Method 1: Empty audiences + entity signals...
#
# 🎬 MOVIE INSIGHTS (10 found):
# ================================================================================
# 🎬 MOVIE: Crip Camp
#    Entity ID: 98095F51-C561-4494-A5C0-A9039DB5DC5A
#    🎯 Affinity: 0.930
#    ⭐ Popularity: 0.839
#    📉 Audience Growth: -0.31
#    📅 Release Year: 2020
#    📅 Release Date: 2020-03-25
#    ⏱️ Duration: 106 minutes
#    🎭 Content Rating: R
#    📝 Plot: Down the road from Woodstock, a revolution blossomed at a ramshackle summer camp for teenagers with disabilities, transforming their lives and igniting a landmark movement.
#    🎭 Production: Higher Ground Productions, Good Gravy Films
#    🎥 Filmed in: Hunter, New York, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/98095F51-C561-4494-A5C0-A9039DB5DC5A-420x-auto.jpg
#    🌐 Official Site: https://www.netflix.com/title/81001496
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: David Attenborough: A Life on Our Planet
#    Entity ID: E56D95FD-03D6-464E-81C2-986B4B0B491E
#    🎯 Affinity: 0.918
#    ⭐ Popularity: 0.951
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2020
#    📅 Release Date: 2020-10-04
#    ⏱️ Duration: 83 minutes
#    🎭 Content Rating: PG
#    📝 Plot: In this documentary David Attenborough, the celebrated naturalist, reflects upon both the defining moments of his lifetime and the devastating changes he has seen. The film provides a snapshot of glob...
#    🎭 Production: Altitude Film Entertainment, World Wildlife Fund, Silverback Films
#    🌍 Released in: United Kingdom
#    🖼️ Image: https://images.qloo.com/i/E56D95FD-03D6-464E-81C2-986B4B0B491E-420x-auto.jpg
#    🌐 Official Site: https://attenborough.film/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: Toni Morrison: The Pieces I Am
#    Entity ID: 8B4B3A11-4543-4E78-8F07-F11B8D658758
#    🎯 Affinity: 0.910
#    ⭐ Popularity: 0.465
#    📈 Audience Growth: 1.10
#    📅 Release Year: 2019
#    📅 Release Date: 2019-06-21
#    ⏱️ Duration: 120 minutes
#    🎭 Content Rating: PG-13
#    📝 Plot: This artful and intimate meditation on the legendary storyteller examines her life, her works and the powerful themes she has confronted throughout her literary career.
#    🎭 Production: Perfect Day Films
#    🎥 Filmed in: New York City, New York, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/8B4B3A11-4543-4E78-8F07-F11B8D658758-420x-auto.jpg
#    🌐 Official Site: https://www.tonimorrisonfilm.com/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: RBG
#    Entity ID: 48850D20-99B1-413F-8994-C4744B5B08AD
#    🎯 Affinity: 0.907
#    ⭐ Popularity: 0.890
#    📉 Audience Growth: -0.44
#    📅 Release Year: 2018
#    📅 Release Date: 2018-07-26
#    ⏱️ Duration: 98 minutes
#    🎭 Content Rating: PG
#    📝 Plot: The exceptional life and career of U.S. Supreme Court Justice Ruth Bader Ginsburg, who has developed a breathtaking legal legacy while becoming an unexpected pop culture icon.
#    🎭 Production: Better Than Fiction Productions, CNN Films, Storyville Films
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/48850D20-99B1-413F-8994-C4744B5B08AD-420x-auto.jpg
#    🌐 Official Site: https://www.rbgmovie.com/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: Disclosure
#    Entity ID: 91B1E32D-3754-4272-BF29-F4701E331576
#    🎯 Affinity: 0.903
#    ⭐ Popularity: 0.814
#    📉 Audience Growth: -0.39
#    📅 Release Year: 2020
#    📅 Release Date: 2020-06-19
#    ⏱️ Duration: 108 minutes
#    🎭 Content Rating: TV-MA
#    📝 Plot: An in-depth look at Hollywood's depiction of transgender people and the impact of those stories on transgender lives and American culture.
#    🎭 Production: Field of Vision (II), Disclosure Films, Bow and Arrow Entertainment
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/91B1E32D-3754-4272-BF29-F4701E331576-420x-auto.jpg
#    🌐 Official Site: https://www.instagram.com/disclosuredoc/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: The Social Dilemma
#    Entity ID: D194DAE4-6C21-4CC7-9BFD-A2FD7AC8EAD6
#    🎯 Affinity: 0.902
#    ⭐ Popularity: 0.977
#    📉 Audience Growth: -0.16
#    📅 Release Year: 2020
#    📅 Release Date: 2020-09-09
#    ⏱️ Duration: 94 minutes
#    🎭 Content Rating: PG-13
#    📝 Plot: Explores the dangerous human impact of social networking; tech experts sound the alarm on their own creations.
#    🎭 Production: The Space Program, Exposure Labs, Argent Pictures
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/D194DAE4-6C21-4CC7-9BFD-A2FD7AC8EAD6-420x-auto.jpg
#    🌐 Official Site: https://www.netflix.com/title/81254224/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: The Game Changers
#    Entity ID: 0F6527DF-CE77-4C3F-9DF5-F0F9E4EA322A
#    🎯 Affinity: 0.900
#    ⭐ Popularity: 0.930
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2018
#    📅 Release Date: 2019-09-16
#    ⏱️ Duration: 86 minutes
#    📝 Plot: A UFC fighter's world is turned upside down when he discovers an elite group of world-renowned athletes and scientists who prove that everything he had been taught about protein was a lie.
#    🎭 Production: Diamond Docs, Oceanic Preservation Society, ReFuel Productions
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/0F6527DF-CE77-4C3F-9DF5-F0F9E4EA322A-420x-auto.jpg
#    🌐 Official Site: http://gamechangersmovie.com/
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: The Banker
#    Entity ID: 4E660642-9CD9-4F67-AC2B-E01CED5D42FA
#    🎯 Affinity: 0.890
#    ⭐ Popularity: 0.953
#    📉 Audience Growth: -0.18
#    📅 Release Year: 2020
#    📅 Release Date: 2020-03-20
#    ⏱️ Duration: 120 minutes
#    🎭 Content Rating: PG-13
#    📝 Plot: In the 1960s, two African-American entrepreneurs hire a working-class white man to pretend to be the head of their business empire while they pose as a janitor and chauffeur.
#    🎭 Production: Romulus Entertainment, Iam21 Entertainment, Hyphenate Films
#    🎥 Filmed in: Atlanta, Georgia, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/4E660642-9CD9-4F67-AC2B-E01CED5D42FA-420x-auto.jpg
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: Don't Worry, He Won't Get Far on Foot
#    Entity ID: F642A27B-906D-43E3-8F14-28E546F183BF
#    🎯 Affinity: 0.888
#    ⭐ Popularity: 0.940
#    📈 Audience Growth: 0.34
#    📅 Release Year: 2018
#    📅 Release Date: 2018-04-04
#    ⏱️ Duration: 114 minutes
#    🎭 Content Rating: R
#    📝 Plot: On the rocky path to sobriety after a life-changing accident, John Callahan discovers the healing power of art, willing his injured hands into drawing hilarious, often controversial cartoons, which br...
#    🎭 Production: Anonymous Content, Iconoclast, Amazon Studios
#    🎥 Filmed in: Portland State University, Portland, Oregon, USA
#    🌍 Released in: France, United States
#    🖼️ Image: https://images.qloo.com/i/F642A27B-906D-43E3-8F14-28E546F183BF-420x-auto.jpg
#    🌐 Official Site: https://www.filmnation.com/library/dont-worry-he-wont-get-far-on-foot
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================
# 🎬 MOVIE: Won't You Be My Neighbor?
#    Entity ID: 36B40B2E-DCBA-48D5-B294-F2E7C7CB67AF
#    🎯 Affinity: 0.887
#    ⭐ Popularity: 0.932
#    📈 Audience Growth: 0.28
#    📅 Release Year: 2018
#    📅 Release Date: 2018-06-29
#    ⏱️ Duration: 95 minutes
#    🎭 Content Rating: PG-13
#    📝 Plot: An exploration of the life, lessons, and legacy of iconic children's television host Fred Rogers.
#    🎭 Production: Impact Partners, Independent Lens, Public Broadcasting Service (PBS)
#    🎥 Filmed in: Dartmouth College, Hanover, New Hampshire, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/36B40B2E-DCBA-48D5-B294-F2E7C7CB67AF-420x-auto.jpg
#    🌐 Official Site: http://www.focusfeatures.com/wont-you-be-my-neighbor
#
# 🔗 Postman URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=10&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City&signal.interests.entities=A753C115-8A82-46B7-8847-0FECC62C4DBD,DFFF5B0D-54C8-42D9-96C2-03193CD571C1
#    ============================================================

# %%
# =============================================================================
# TEST 2: Multi-Entity Search with get_entity_info
# =============================================================================
print("=" * 70)
print("TEST 2: Multi-Entity Search (get_entity_info)")
print("=" * 70)

# Search for multiple entities with different types
search_queries = ["Chelsea FC", "Nike", "Taylor Swift", "Starbucks", "Manchester"]

signals_comprehensive = QlooSignals(
    demographics={"age": "25_to_29", "gender": "female"},
    location={"query": "New York City"}
)

print(f"🔍 Searching for {len(search_queries)} entities with comprehensive signals...")
print(f"Queries: {search_queries}")
print(f"Demographics: {signals_comprehensive.demographics}")
print(f"Location: {signals_comprehensive.location}")
print()

# Use the new get_entity_info method to search for all entities
multi_search_result = client.get_entity_info(
    queries=search_queries,
    entity_types=["brand", "artist", "place", "people"],  # Multiple entity types
    signals=signals_comprehensive,
    limit_per_query=5
)

print(f"Overall success: {multi_search_result['success']}")
print(f"Total entities found: {multi_search_result['total_entities_found']}")
print()

# Print summary
summary = multi_search_result['summary']
print("📊 SEARCH SUMMARY:")
print(f"  • Queries processed: {summary['queries_processed']}")
print(f"  • Successful queries: {summary['successful_queries']}")  
print(f"  • Total entities found: {summary['total_entities']}")
print()

# Print detailed results for each query
print("📋 DETAILED RESULTS BY QUERY:")
for query, result in multi_search_result['query_results'].items():
    print(f"\n🔎 Query: '{query}'")
    if result['success']:
        entities = result['entities']
        print(f"  ✅ Found {len(entities)} entities:")
        for i, entity in enumerate(entities, 1):
            score_info = f" (affinity: {entity.affinity_score:.3f})" if entity.affinity_score else ""
            pop_info = f" [pop: {entity.popularity:.3f}]" if entity.popularity else ""
            print(f"    {i}. {entity.name} [{entity.entity_type}]{score_info}{pop_info}")
            print(f"       ID: {entity.id}")
    else:
        print(f"  ❌ Failed: {result['error']}")

print()
# Out:
# ======================================================================
# TEST 2: Multi-Entity Search (get_entity_info)
# ======================================================================
# 🔍 Searching for 5 entities with comprehensive signals...
# Queries: ['Chelsea FC', 'Nike', 'Taylor Swift', 'Starbucks', 'Manchester']
# Demographics: {'age': '25_to_29', 'gender': 'female'}
# Location: {'query': 'New York City'}
#
# 🔍 Searching for 5 entities...
#   📍 Query 1/5: 'Chelsea FC'
#     ✅ Found 5 entities:
#       • Chelsea F.C. [brand]
#       • Chelsea Football Club Women [brand]
#       • Chelsea FC [artist]
#       ... and 2 more
#   📍 Query 2/5: 'Nike'
#     ✅ Found 5 entities:
#       • Nike [brand]
#       • Nike [place]
#       • Nike [place]
#       ... and 2 more
#   📍 Query 3/5: 'Taylor Swift'
#     ✅ Found 5 entities:
#       • Taylor Swift [artist]
#       • Taylor Swift [people]
#       • Taylor Swift, Bon Iver [artist]
#       ... and 2 more
#   📍 Query 4/5: 'Starbucks'
#     ✅ Found 5 entities:
#       • Starbucks [place]
#       • Starbucks [brand]
#       • Starbucks [place]
#       ... and 2 more
#   📍 Query 5/5: 'Manchester'
#     ✅ Found 5 entities:
#       • Manchester United F.C. [brand]
#       • Manchester [place]
#       • Manchester [place]
#       ... and 2 more
# Overall success: True
# Total entities found: 25
#
# 📊 SEARCH SUMMARY:
#   • Queries processed: 5
#   • Successful queries: 5
#   • Total entities found: 25
#
# 📋 DETAILED RESULTS BY QUERY:
#
# 🔎 Query: 'Chelsea FC'
#   ✅ Found 5 entities:
#     1. Chelsea F.C. [brand] [pop: 1.000]
#        ID: A21D248A-7379-458E-A3BE-7B8C4B961AF6
#     2. Chelsea Football Club Women [brand] [pop: 0.983]
#        ID: C3A3CB61-F5D4-41D9-89FF-6C816D951B38
#     3. Chelsea FC [artist] [pop: 0.783]
#        ID: B7B5943E-AC80-4C90-9A38-E776F068AAAA
#     4. Chelsea FC Megastore [place] [pop: 0.947]
#        ID: 985685E8-BD26-4EEB-AA94-A4F7F7BE69AD
#     5. Chelsea FC Museum [place] [pop: 0.936]
#        ID: 8890B440-5693-4721-8175-4A312E4358AD
#
# 🔎 Query: 'Nike'
#   ✅ Found 5 entities:
#     1. Nike [brand] [pop: 1.000]
#        ID: C70CE2B8-0AD1-4150-BF18-5A6347F2E860
#     2. Nike [place] [pop: 0.989]
#        ID: 279F2E1B-7D9D-47B5-BCE7-0E583180298C
#     3. Nike [place] [pop: 0.973]
#        ID: DDC1CCCE-8659-4BD8-A48B-BAFB8D7F4AC4
#     4. Nike [place] [pop: 0.972]
#        ID: 278AF219-4A77-4099-AE31-A13F24EC6FCC
#     5. Nike [place] [pop: 0.968]
#        ID: F4620E84-0B34-4AF8-AFC7-B84980BB5B3F
#
# 🔎 Query: 'Taylor Swift'
#   ✅ Found 5 entities:
#     1. Taylor Swift [artist] [pop: 1.000]
#        ID: 4BBEF799-A0C4-4110-AB01-39216993C312
#     2. Taylor Swift [people] [pop: 0.982]
#        ID: 3C9EEC3A-F4FE-48A4-B89F-97375F292448
#     3. Taylor Swift, Bon Iver [artist] [pop: 0.632]
#        ID: 42F29D24-DE96-4311-A069-273DCB1C1285
#     4. Taylor Swift & Seeb [artist] [pop: 0.318]
#        ID: 30B19C02-7F75-4665-82A2-8125B51D371F
#     5. Taylor Swift, Gary Lightbody [artist] [pop: 0.222]
#        ID: 2236402F-EF5E-4337-A14C-539EE48006E8
#
# 🔎 Query: 'Starbucks'
#   ✅ Found 5 entities:
#     1. Starbucks [place] [pop: 1.000]
#        ID: 8BEC8ADB-6E51-4F45-A20F-4FD04B1F383F
#     2. Starbucks [brand] [pop: 1.000]
#        ID: B13C02E3-BA3C-4B39-85B4-ACF12FEBC892
#     3. Starbucks [place] [pop: 0.998]
#        ID: 48AFEC14-7A54-49C7-8090-FD6BF4579B03
#     4. Starbucks [place] [pop: 0.996]
#        ID: D109F7C8-E820-416A-A211-4A40CE852CC4
#     5. Starbucks [place] [pop: 0.996]
#        ID: 04E7ECC0-63B7-49CF-9798-689A9B852B76
#
# 🔎 Query: 'Manchester'
#   ✅ Found 5 entities:
#     1. Manchester United F.C. [brand] [pop: 1.000]
#        ID: D719B77A-E9A2-4E07-BF7B-F6ED1C9521C6
#     2. Manchester [place] [pop: 0.779]
#        ID: 6BA64A11-E7E9-499F-8843-4769DA80FEF7
#     3. Manchester [place] [pop: 0.655]
#        ID: 2B3FA2F9-020E-4E6F-B7A9-1805770A9D6F
#     4. Manchester Academy [place] [pop: 1.000]
#        ID: D6CC7486-D80D-456B-A43A-FFC40CE961BB
#     5. Manchester Arndale Shopping Centre [place] [pop: 1.000]
#        ID: 1FE9B45C-A444-44F3-BAD2-E2972057FB6B

# %%
# =============================================================================
# TEST 4: Search with Popularity and Rating Filters
# =============================================================================
print("=" * 70) 
print("TEST 4: Search with Filters")
print("=" * 70)

print("🔍 Searching for popular brands with minimum popularity...")
filtered_result = client.search_entities(
    query="English Football teams",
    entity_types=["brand"],
    signals=signals_comprehensive,
    limit=20,
    min_popularity=0.1,  # Minimum popularity threshold
    sort_by="popularity"  # Sort by popularity
)

if filtered_result['success']:
    print(f"Found {filtered_result['total_found']} popular coffee brands:")
    for entity in filtered_result['entities']:
        pop_info = f" [popularity: {entity.popularity:.3f}]" if entity.popularity else ""
        print(f"  • {entity.name}{pop_info}")
else:
    print(f"Search failed: {filtered_result['error']}")

print()
# Out:
# ======================================================================
# TEST 4: Search with Filters
# ======================================================================
# 🔍 Searching for popular brands with minimum popularity...
# Found 20 popular coffee brands:
#   • Nike [popularity: 1.000]
#   • FC Barcelona [popularity: 1.000]
#   • Premier League [popularity: 1.000]
#   • Real Madrid CF [popularity: 1.000]
#   • Manchester United F.C. [popularity: 1.000]
#   • Chelsea F.C. [popularity: 1.000]
#   • Juventus FC [popularity: 1.000]
#   • Liverpool F.C. [popularity: 1.000]
#   • National Football League [popularity: 1.000]
#   • Manchester City F.C. [popularity: 0.999]
#   • PSG [popularity: 0.999]
#   • FIFA 23 [popularity: 0.999]
#   • Arsenal F.C. [popularity: 0.999]
#   • Warner Bros. Pictures [popularity: 0.999]
#   • Al Arabiya [popularity: 0.999]
#   • La Liga [popularity: 0.999]
#   • Fifa World Cup [popularity: 0.999]
#   • Tottenham Hotspur F.C. [popularity: 0.998]
#   • Brazil national football team [popularity: 0.998]
#   • Union of European Football Associations [popularity: 0.998]

# %%
signals = QlooSignals(
    demographics={"age": "25_to_29", "gender": "female"},
    location={"query": "New York City"}
)

print("🔍 Finding audiences with entity queries...")
print(f"Signal: {signals}")


result_queries = client.find_audiences(signals=signals, limit=10)

print(f"\n📊 Found {result_queries['total_found']} audiences using entity queries:")
for i, audience in enumerate(result_queries['audiences'][:5], 1):
    print(f"{i}. {audience.name} (ID: {audience.id})")
    print(f"   Type: {audience.parent_type}")
    print(f"   Entity ID: {audience.entity_id}")
    print()


# Get some audience IDs for insights
audience_ids = [aud.id for aud in result_queries['audiences'][:3]]
# Out:
# 🔍 Finding audiences with entity queries...
# Signal: QlooSignals(demographics={'age': '25_to_29', 'gender': 'female'}, location={'query': 'New York City'}, entity_ids=None, entity_queries=None)
#
# 📊 Found 70 audiences using entity queries:
# 1. Health And Beauty (ID: urn:audience:hobbies_and_interests:health_and_beauty)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 8F0407D3-64F3-47BF-A6B1-BA4C30465F71
#
# 2. Adventuring (ID: urn:audience:hobbies_and_interests:adventuring)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: DBDCB7B7-B015-425F-9C3E-619C9C4245EB
#
# 3. Photography (ID: urn:audience:hobbies_and_interests:photography)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 7DCA3589-E6FF-4582-BE24-5A2D09D71336
#
# 4. Tattoos (ID: urn:audience:hobbies_and_interests:tattoos)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 965CD575-A0AD-4128-88B6-DE0C599D644F
#
# 5. Meditation (ID: urn:audience:hobbies_and_interests:meditation)
#    Type: urn:audience:hobbies_and_interests
#    Entity ID: 1C3735D4-FE2D-4CDE-811A-9B2BFE767DAD

# %%
# Get general tag insights - SAFE VERSION
tag_insights = client.get_tag_insights(
    audience_ids=audience_ids,
    signals=signals,
    limit=5
)

if tag_insights['success'] and tag_insights['results'].get('tags'):
    print("TAG INSIGHTS:")
    for tag in tag_insights['results']['tags']:
        print(f"- {tag['name']} ({tag['tag_id']})")
        
        # Safe access to affinity score
        affinity = tag.get('query', {}).get('affinity', 'N/A')
        print(f"  Affinity: {affinity}")
        print(f"  Type: {tag.get('subtype', 'Unknown')}")
        print(f"  Applies to: {', '.join(tag.get('types', []))}")
        print()
else:
    print("No tags found")
print(f"\nInsights URL: {tag_insights['postman_url']}")


# Get specific tag types if needed - SAFE VERSION
lifestyle_tags = client.get_tag_insights(
    audience_ids=audience_ids,
    tag_filter="urn:tag:lifestyle:qloo",
    limit=10
)

if lifestyle_tags['success'] and lifestyle_tags['results'].get('tags'):
    print("LIFESTYLE TAG INSIGHTS:")
    for tag in lifestyle_tags['results']['tags']:
        affinity = tag.get('query', {}).get('affinity', 0.0)
        print(f"- {tag['name']}: {affinity:.3f}")
else:
    print("No lifestyle tags found")

print(f"\nInsights URL: {lifestyle_tags['postman_url']}")
# Out:
# TAG INSIGHTS:
# - Reddit (urn:tag:keyword:qloo:reddit)
#   Affinity: 0.9908034138199858
#   Type: urn:tag:keyword:qloo
#   Applies to: urn:entity:tv_show, urn:entity:podcast, urn:entity:movie
#
# - Heartwarming (urn:tag:subgenre:qloo:heartwarming)
#   Affinity: 0.9740318298499882
#   Type: urn:tag:subgenre:qloo
#   Applies to: urn:entity:tv_show, urn:entity:movie
#
# - Marriage (urn:tag:theme:qloo:marriage)
#   Affinity: 0.9714221171184738
#   Type: urn:tag:theme:qloo
#   Applies to: urn:entity:podcast
#
# - Festively enchanting (urn:tag:style:qloo:festively_enchanting)
#   Affinity: 0.9713628858451453
#   Type: urn:tag:style:qloo
#   Applies to: urn:entity:movie
#
# - Family bond (urn:tag:archetype:qloo:family_bond)
#   Affinity: 0.9712550626695016
#   Type: urn:tag:archetype:qloo
#   Applies to: urn:entity:tv_show, urn:entity:podcast, urn:entity:movie
#
#
# Insights URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:tag&signal.demographics.audiences=urn:audience:hobbies_and_interests:health_and_beauty,urn:audience:hobbies_and_interests:adventuring,urn:audience:hobbies_and_interests:photography&take=5&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City
# LIFESTYLE TAG INSIGHTS:
# - Trendy: 0.000
# - exclusive events: 0.000
# - accessible: 0.000
# - Culture: 0.000
# - action sports: 0.000
# - beauty enhancement: 0.000
# - urban adventure: 0.000
# - exclusive social circles: 0.000
# - variety: 0.000
# - innovation-driven: 0.000
#
# Insights URL: https://hackathon.api.qloo.com/v2/insights?filter.type=urn:tag&signal.demographics.audiences=urn:audience:hobbies_and_interests:health_and_beauty,urn:audience:hobbies_and_interests:adventuring,urn:audience:hobbies_and_interests:photography&take=10&filter.tag.types=urn:tag:lifestyle:qloo

# %% [markdown]
# Brand Insights

# %%
brand_insights = client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="brand",
    limit=5
)

def display_brand_insights(entity):
    """Display comprehensive brand information"""
    print(f"🏢 BRAND: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    # Brand description
    props = entity.get('properties', {})
    description = props.get('short_description', 'No description available')
    print(f"   📝 Description: {description}")
    
    # Image URL if available
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    # External data (if available)
    if 'external' in entity:
        for platform, data in entity['external'].items():
            if data and isinstance(data, list) and len(data) > 0:
                platform_data = data[0]
                print(f"   🔗 {platform.title()}: {platform_data.get('url', 'Available')}")
    
    print("   " + "="*60)



"""Display all brand insights"""
if brand_insights['success'] and brand_insights['results'].get('entities'):
    entities = brand_insights['results']['entities']
    print(f"\n🏢 BRAND INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_brand_insights(entity)
else:
    print(f"\n❌ BRANDS: FAILED - {brand_insights.get('error', 'Unknown error')}")
# Out:
# 🏢 BRAND INSIGHTS (5 found):
# ================================================================================
# 🏢 BRAND: Wells Fargo Autograph Card
#    Entity ID: 2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A
#    🎯 Affinity: 0.958
#    ⭐ Popularity: 0.981
#    ➡️ Audience Growth: 0.00
#    📝 Description: Wells Fargo Autograph Card is a Visa rewards credit card offering 3X points on top spending categories, no annual fee, and exclusive event access.
#    🖼️ Image: https://images.qloo.com/i/2CA9E6A1-DAE0-4423-9881-780F9CE3FE8A-420x-auto.jpg
#    ============================================================
# 🏢 BRAND: Barclay's Gap Good Rewards Mastercard
#    Entity ID: FB200B38-DFBE-4D9A-8BD0-8777591D188C
#    🎯 Affinity: 0.957
#    ⭐ Popularity: 0.475
#    ➡️ Audience Growth: 0.00
#    📝 Description: The Gap Good Rewards Mastercard is a credit card issued by Barclays Bank offering rewards and discounts for purchases at Gap Inc. brands.
#    🖼️ Image: https://images.qloo.com/i/FB200B38-DFBE-4D9A-8BD0-8777591D188C-420x-auto.jpg
#    ============================================================
# 🏢 BRAND: MM.LaFleur
#    Entity ID: C8B8E4B0-077B-45E3-BB83-56416941ED3B
#    🎯 Affinity: 0.955
#    ⭐ Popularity: 0.833
#    ➡️ Audience Growth: 0.00
#    📝 Description: M.M.LaFleur is a women's fashion brand offering thoughtfully designed, washable, wrinkle-resistant clothing including dresses, blazers, and travel wear.
#    🖼️ Image: https://images.qloo.com/i/C8B8E4B0-077B-45E3-BB83-56416941ED3B-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Twitter: Available
#    ============================================================
# 🏢 BRAND: Girlboss
#    Entity ID: 2F7AE8C0-77ED-4ADD-A33A-255D0D969F24
#    🎯 Affinity: 0.955
#    ⭐ Popularity: 0.991
#    ➡️ Audience Growth: 0.00
#    📝 Description: Girlboss is a community and media brand empowering ambitious women with career inspiration, insights, and resources for success on their own terms.
#    🖼️ Image: https://images.qloo.com/i/2F7AE8C0-77ED-4ADD-A33A-255D0D969F24-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Twitter: Available
#    ============================================================
# 🏢 BRAND: Modern Citizen
#    Entity ID: AF426F49-A936-4F82-87E0-4D2A023EE077
#    🎯 Affinity: 0.954
#    ⭐ Popularity: 0.845
#    ➡️ Audience Growth: 0.00
#    📝 Description: Modern Citizen is a women's fashion label known for versatile, luxurious basics designed to last for years.
#    🖼️ Image: https://images.qloo.com/i/AF426F49-A936-4F82-87E0-4D2A023EE077-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Twitter: Available
#    ============================================================

# %% [markdown]
# Artist

# %%
artist_insights = client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="artist",
    limit=5
)

# %%
def display_artist_insights(entity):
    """Display comprehensive artist information"""
    print(f"🎤 ARTIST: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Description
    description = props.get('short_description', {})
    if isinstance(description, dict) and 'value' in description:
        print(f"   📝 Description: {description['value']}")
    elif isinstance(description, str):
        print(f"   📝 Description: {description}")
    
    # Birth info
    if 'date_of_birth' in props:
        print(f"   🎂 Born: {props['date_of_birth']}")
    if 'place_of_birth' in props:
        print(f"   📍 Birthplace: {props['place_of_birth']}")
    
    # Alternative names
    if 'akas' in props and props['akas']:
        akas = [aka.get('value', aka) for aka in props['akas'][:3] if aka]
        print(f"   👥 Also known as: {', '.join(akas)}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    # External platforms
    if 'external' in entity:
        for platform, data in entity['external'].items():
            if data and isinstance(data, list) and len(data) > 0:
                platform_data = data[0]
                if platform == 'spotify':
                    followers = platform_data.get('followers', 'N/A')
                    listeners = platform_data.get('monthly_listeners', 'N/A')
                    print(f"   🎵 Spotify: {followers} followers, {listeners} monthly listeners")
                else:
                    print(f"   🔗 {platform.title()}: Available")
    
    print("   " + "="*60)



"""Display all artist insights"""
if artist_insights['success'] and artist_insights['results'].get('entities'):
    entities = artist_insights['results']['entities']
    print(f"\n🎤 ARTIST INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_artist_insights(entity)
else:
    print(f"\n❌ ARTISTS: FAILED - {artist_insights.get('error', 'Unknown error')}")
# Out:
# 🎤 ARTIST INSIGHTS (5 found):
# ================================================================================
# 🎤 ARTIST: H.E.R.
#    Entity ID: FA0DCE63-EC21-49C9-8741-8731AD9E0EAD
#    🎯 Affinity: 0.990
#    ⭐ Popularity: 0.984
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 1997-06-27
#    📍 Birthplace: Vallejo, Solano County, Californ
#    👥 Also known as: H.E.R., H.E.R., H.E.R.
#    🖼️ Image: https://images.qloo.com/i/FA0DCE63-EC21-49C9-8741-8731AD9E0EAD-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Wikidata: Available
#    🔗 Twitter: Available
#    🔗 Imdb: Available
#    🔗 Facebook: Available
#    🔗 Lastfm: Available
#    🔗 Musicbrainz: Available
#    ============================================================
# 🎤 ARTIST: Lea Michele
#    Entity ID: A55ABACC-8EDE-417F-BDF0-2E7422C7E878
#    🎯 Affinity: 0.989
#    ⭐ Popularity: 0.987
#    📈 Audience Growth: 2.39
#    🎂 Born: 1986-08-29
#    📍 Birthplace: The Bronx, New York, New York, U
#    👥 Also known as: लिया मिशेल, Леа Мишел, Lea Michele
#    🖼️ Image: https://images.qloo.com/i/A55ABACC-8EDE-417F-BDF0-2E7422C7E878-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Wikidata: Available
#    🔗 Twitter: Available
#    🔗 Imdb: Available
#    🔗 Facebook: Available
#    🔗 Lastfm: Available
#    🔗 Musicbrainz: Available
#    🎵 Spotify: 450067 followers, 1449276 monthly listeners
#    ============================================================
# 🎤 ARTIST: Tori Kelly
#    Entity ID: AE7FDFFB-571A-4223-95FA-96165D6E8EF5
#    🎯 Affinity: 0.989
#    ⭐ Popularity: 0.983
#    📈 Audience Growth: 0.59
#    🎂 Born: 1992-12-14
#    👥 Also known as: Tori Kelly, Tori Kelly, توري كيلي
#    🖼️ Image: https://images.qloo.com/i/AE7FDFFB-571A-4223-95FA-96165D6E8EF5-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Wikidata: Available
#    🔗 Twitter: Available
#    🔗 Imdb: Available
#    🔗 Facebook: Available
#    🔗 Lastfm: Available
#    🔗 Musicbrainz: Available
#    🎵 Spotify: 1840877 followers, 11055855 monthly listeners
#    ============================================================
# 🎤 ARTIST: Hozier
#    Entity ID: 7D903E2F-70AB-44CB-AA88-82501E6D04DD
#    🎯 Affinity: 0.989
#    ⭐ Popularity: 0.999
#    📉 Audience Growth: -0.28
#    🎂 Born: 1990-03-17
#    📍 Birthplace: Bray, County Wicklow, Leinster,
#    👥 Also known as: Andrew Hozier-Byrne, Hozier, Hozier
#    🖼️ Image: https://images.qloo.com/i/7D903E2F-70AB-44CB-AA88-82501E6D04DD-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Wikidata: Available
#    🔗 Twitter: Available
#    🔗 Imdb: Available
#    🔗 Facebook: Available
#    🔗 Lastfm: Available
#    🔗 Musicbrainz: Available
#    🎵 Spotify: 4336785 followers, 15010176 monthly listeners
#    ============================================================
# 🎤 ARTIST: Lana Del Rey
#    Entity ID: 63BBE4D8-D721-466F-907C-D0007E9B6665
#    🎯 Affinity: 0.989
#    ⭐ Popularity: 1.000
#    📉 Audience Growth: -0.64
#    🎂 Born: 1985-06-21
#    📍 Birthplace: New York, New York, United State
#    👥 Also known as: Lana Del Rey, Елізабет Ґрант, Grānta
#    🖼️ Image: https://images.qloo.com/i/63BBE4D8-D721-466F-907C-D0007E9B6665-420x-auto.jpg
#    🔗 Instagram: Available
#    🔗 Wikidata: Available
#    🔗 Goodreads: Available
#    🔗 Twitter: Available
#    🔗 Imdb: Available
#    🔗 Facebook: Available
#    🔗 Lastfm: Available
#    🔗 Musicbrainz: Available
#    🎵 Spotify: 11734343 followers, 17397761 monthly listeners
#    ============================================================

# %% [markdown]
# Place

# %%
place_insights = client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="place",
    limit=5
)

# %%
def display_place_insights(entity):
    """Display comprehensive place information"""
    print(f"📍 PLACE: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Address
    if 'address' in props:
        print(f"   🏠 Address: {props['address']}")
    
    # Business details
    if 'business_rating' in props:
        print(f"   ⭐ Business Rating: {props['business_rating']}/5.0")
    
    if 'phone' in props:
        print(f"   📞 Phone: {props['phone']}")
    
    if 'website' in props:
        print(f"   🌐 Website: {props['website']}")
    
    # Neighborhood/Location
    if 'neighborhood' in props:
        print(f"   🏘️ Neighborhood: {props['neighborhood']}")
    
    # Hours (simplified)
    if 'hours' in props and props['hours']:
        print(f"   🕐 Hours: Available")
    
    # Status
    if 'is_closed' in props:
        status = "❌ Closed" if props['is_closed'] else "✅ Open"
        print(f"   {status}")
    
    # Keywords/Popular terms
    if 'keywords' in props and props['keywords']:
        top_keywords = [kw.get('name', str(kw)) for kw in props['keywords'][:5]]
        print(f"   🏷️ Keywords: {', '.join(top_keywords)}")
    
    # Coordinates
    if 'location' in entity:
        loc = entity['location']
        lat = loc.get('lat', 'N/A')
        lon = loc.get('lon', 'N/A')
        print(f"   🗺️ Coordinates: {lat}, {lon}")
    
    # Categories from tags
    if 'tags' in entity:
        categories = [tag.get('name', '') for tag in entity['tags'][:3] if 'category' in tag.get('id', '')]
        if categories:
            print(f"   🎪 Categories: {', '.join(categories)}")
    
    print("   " + "="*60)



"""Display all place insights"""
if place_insights['success'] and place_insights['results'].get('entities'):
    entities = place_insights['results']['entities']
    print(f"\n📍 PLACE INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_place_insights(entity)
else:
    print(f"\n❌ PLACES: FAILED - {place_insights.get('error', 'Unknown error')}")
# Out:
# 📍 PLACE INSIGHTS (5 found):
# ================================================================================
# 📍 PLACE: Muse Paintbar - Tribeca
#    Entity ID: 921A958F-552D-43EF-AD42-9EF5BA3E7E6B
#    🎯 Affinity: 0.994
#    ⭐ Popularity: 0.976
#    ➡️ Audience Growth: 0.00
#    🏠 Address: 329 Greenwich St New York, NY 10013
#    ⭐ Business Rating: 4.7/5.0
#    📞 Phone: +18886076873
#    🌐 Website: https://www.musepaintbar.com/events/NYC-paint-bar
#    🏘️ Neighborhood: Tribeca
#    🕐 Hours: Available
#    ✅ Open
#    🏷️ Keywords: instructor, birthday, fun, atmosphere, night
#    🗺️ Coordinates: 40.717693, -74.01036
#    ============================================================
# 📍 PLACE: Sussex County Sunflower Maze
#    Entity ID: 1D607F0D-DCCD-4CB8-A136-16D0074444A2
#    🎯 Affinity: 0.991
#    ⭐ Popularity: 0.997
#    ➡️ Audience Growth: 0.00
#    🏠 Address: 101 Co Rd 645 Sandyston, NJ 07826
#    ⭐ Business Rating: 4.5/5.0
#    📞 Phone: +18337866293
#    🌐 Website: http://www.sussexcountysunflowermaze.com/
#    🏘️ Neighborhood: Sandyston Township
#    🕐 Hours: Available
#    ✅ Open
#    🏷️ Keywords: sunflowers, beautiful, photos, kids, season
#    🗺️ Coordinates: 41.24205, -74.80346
#    ============================================================
# 📍 PLACE: Carpenter Hotel
#    Entity ID: 6A6A4401-9343-4BA4-A2EF-71A1FD2E1954
#    🎯 Affinity: 0.991
#    ⭐ Popularity: 0.989
#    📉 Audience Growth: -2.21
#    🏠 Address: 400 Josephine St Austin, TX 78704
#    ⭐ Business Rating: 4.6/5.0
#    📞 Phone: +15126825300
#    🌐 Website: http://www.carpenterhotel.com/
#    🏘️ Neighborhood: Zilker
#    ✅ Open
#    🏷️ Keywords: coffee shop, design, aesthetic, cocktails, concrete
#    🗺️ Coordinates: 30.262213, -97.75872
#    ============================================================
# 📍 PLACE: Treebones Resort
#    Entity ID: 76DFBAC4-920F-4E26-9090-781AB5F91F6A
#    🎯 Affinity: 0.990
#    ⭐ Popularity: 0.991
#    ➡️ Audience Growth: 0.00
#    🏠 Address: 71895 CA-1 Big Sur, CA 93920
#    ⭐ Business Rating: 4.6/5.0
#    📞 Phone: +18774244787
#    🌐 Website: http://www.treebonesresort.com/
#    ✅ Open
#    🏷️ Keywords: yurts, sushi, ocean, tent, hiking
#    🗺️ Coordinates: 35.884254, -121.4553
#    🎪 Categories: Campground, Gift Shop
#    ============================================================
# 📍 PLACE: Conservatory of Flowers
#    Entity ID: 870157BB-EA10-4A37-A092-FC89F443188E
#    🎯 Affinity: 0.990
#    ⭐ Popularity: 0.990
#    📉 Audience Growth: -1.20
#    🏠 Address: 100 John F Kennedy Dr San Francisco, CA 94118
#    ⭐ Business Rating: 4.7/5.0
#    📞 Phone: +14156611316
#    🌐 Website: https://gggp.org/conservatory-of-flowers/
#    🕐 Hours: Available
#    ✅ Open
#    🏷️ Keywords: greenhouse, tropical, building, humid, dahlia
#    🗺️ Coordinates: 37.772617, -122.46026
#    ============================================================

# %% [markdown]
# Movie

# %%
movie_insights = client.get_entity_insights(
    audience_ids=[],
    signals=signals,
    entity_type="movie",
    limit=5
)

def display_movie_insights(entity):
    """Display comprehensive movie information"""
    print(f"🎬 MOVIE: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Release information
    if 'release_year' in props:
        print(f"   📅 Release Year: {props['release_year']}")
    if 'release_date' in props:
        print(f"   📅 Release Date: {props['release_date']}")
    
    # Duration
    if 'duration' in props:
        print(f"   ⏱️ Duration: {props['duration']} minutes")
    
    # Rating
    if 'content_rating' in props:
        print(f"   🎭 Content Rating: {props['content_rating']}")
    
    # Description
    if 'description' in props:
        description = props['description'][:200] + "..." if len(props['description']) > 200 else props['description']
        print(f"   📝 Plot: {description}")
    
    # Production details
    if 'production_companies' in props and props['production_companies']:
        companies = props['production_companies'][:3]
        print(f"   🎭 Production: {', '.join(companies)}")
    
    # Filming location
    if 'filming_location' in props:
        print(f"   🎥 Filmed in: {props['filming_location']}")
    
    # Release countries
    if 'release_country' in props and props['release_country']:
        countries = props['release_country'][:3]
        print(f"   🌍 Released in: {', '.join(countries)}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    # Websites
    if 'websites' in props and props['websites']:
        print(f"   🌐 Official Site: {props['websites'][0]}")
    
    print("   " + "="*60)



"""Display all movie insights"""
if movie_insights['success'] and movie_insights['results'].get('entities'):
    entities = movie_insights['results']['entities']
    print(f"\n🎬 MOVIE INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_movie_insights(entity)
else:
    print(f"\n❌ MOVIES: FAILED - {movie_insights.get('error', 'Unknown error')}")
# Out:
# 🎬 MOVIE INSIGHTS (5 found):
# ================================================================================
# 🎬 MOVIE: Little Women
#    Entity ID: 969911E8-7092-43D9-8C7D-C7547EAE3C00
#    🎯 Affinity: 0.995
#    ⭐ Popularity: 0.992
#    📈 Audience Growth: 0.30
#    📅 Release Year: 2019
#    📅 Release Date: 2019-12-25
#    ⏱️ Duration: 135 minutes
#    🎭 Content Rating: PG
#    📝 Plot: 19th century Massachusetts. While the March sisters - Jo, Meg, Amy, and Beth - enter the threshold of womanhood, they go through many ups and downs in life and endeavor to make important decisions tha...
#    🎭 Production: Regency Enterprises, DiNovi Pictures, Columbia Pictures
#    🎥 Filmed in: Concord, Massachusetts, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/969911E8-7092-43D9-8C7D-C7547EAE3C00-420x-auto.jpg
#    🌐 Official Site: http://www.facebook.com/LittleWomenMovie/
#    ============================================================
# 🎬 MOVIE: Booksmart
#    Entity ID: 85C499B8-4E79-49C0-90F0-19C33C1D32D8
#    🎯 Affinity: 0.994
#    ⭐ Popularity: 0.979
#    📈 Audience Growth: 0.20
#    📅 Release Year: 2019
#    📅 Release Date: 2019-05-24
#    ⏱️ Duration: 102 minutes
#    🎭 Content Rating: R
#    📝 Plot: On the eve of their high-school graduation, two academic superstars and best friends realize they should have worked less and played more. Determined not to fall short of their peers, the girls try to...
#    🎭 Production: Annapurna Pictures, Gloria Sanchez Productions
#    🎥 Filmed in: Los Angeles, California, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/85C499B8-4E79-49C0-90F0-19C33C1D32D8-420x-auto.jpg
#    🌐 Official Site: http://www.annapurna.pictures/films/booksmart
#    ============================================================
# 🎬 MOVIE: The Hate U Give
#    Entity ID: 0BF15BDE-3915-4EA1-9612-F8642E033BEE
#    🎯 Affinity: 0.992
#    ⭐ Popularity: 0.944
#    📉 Audience Growth: -0.04
#    📅 Release Year: 2018
#    📅 Release Date: 2018-10-19
#    ⏱️ Duration: 133 minutes
#    🎭 Content Rating: PG-13
#    📝 Plot: Starr witnesses the fatal shooting of her childhood best friend Khalil at the hands of a police officer. Now, facing pressure from all sides of the community, Starr must find her voice and stand up fo...
#    🎭 Production: TSG Entertainment, State Street Pictures, Fox 2000 Pictures
#    🎥 Filmed in: Atlanta, Georgia, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/0BF15BDE-3915-4EA1-9612-F8642E033BEE-420x-auto.jpg
#    🌐 Official Site: https://www.facebook.com/TheHateUGiveMovie
#    ============================================================
# 🎬 MOVIE: Then Came You
#    Entity ID: 5D2627FB-04BA-40B7-9552-3448BA4B031E
#    🎯 Affinity: 0.991
#    ⭐ Popularity: 0.880
#    📈 Audience Growth: 0.34
#    📅 Release Year: 2018
#    📅 Release Date: 2019-02-01
#    ⏱️ Duration: 97 minutes
#    🎭 Content Rating: Not Rated
#    📝 Plot: A hypochondriac working as an airport baggage handler is forced to confront his fears when a British teenager with a terminal illness enlists him to help her carry out her eccentric bucket list.
#    🎭 Production: BCDF Pictures
#    🎥 Filmed in: Bop to Tottom, Kingston, New York, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/5D2627FB-04BA-40B7-9552-3448BA4B031E-420x-auto.jpg
#    ============================================================
# 🎬 MOVIE: Beautiful Boy
#    Entity ID: FC877810-FE6F-4D25-83B5-015B43E2018F
#    🎯 Affinity: 0.985
#    ⭐ Popularity: 0.977
#    📈 Audience Growth: 0.18
#    📅 Release Year: 2018
#    📅 Release Date: 2018-10-25
#    ⏱️ Duration: 120 minutes
#    🎭 Content Rating: R
#    📝 Plot: A family coping with addiction over many years goes through the heartbreaking and inspiring experience of survival, relapse and recovery.
#    🎭 Production: Plan B Entertainment, Amazon Studios, Big Indie Pictures
#    🎥 Filmed in: Marin County, California, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/FC877810-FE6F-4D25-83B5-015B43E2018F-420x-auto.jpg
#    🌐 Official Site: https://www.facebook.com/BeautifulBoyMovie/
#    ============================================================

# %%
movie_insights
# Out:
# {'success': True,
#  'entity_type': 'movie',
#  'audience_ids': [],
#  'request_method': 'GET',
#  'params_used': {'filter.type': 'urn:entity:movie',
#   'take': '5',
#   'signal.demographics.age': '25_to_29',
#   'signal.demographics.gender': 'female',
#   'signal.location.query': 'New York City'},
#  'results': {'entities': [{'name': 'Little Women',
#     'entity_id': '969911E8-7092-43D9-8C7D-C7547EAE3C00',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:movie',
#     'properties': {'release_year': 2019,
#      'release_date': '2019-12-25',
#      'description': '19th century Massachusetts. While the March sisters - Jo, Meg, Amy, and Beth - enter the threshold of womanhood, they go through many ups and downs in life and endeavor to make important decisions that can affect their future.',
#      'content_rating': 'PG',
#      'duration': 135,
#      'image': {'url': 'https://images.qloo.com/i/969911E8-7092-43D9-8C7D-C7547EAE3C00-420x-auto.jpg'},
#      'akas': [{'value': 'نساء صغيرات', 'languages': ['ar']},
#       {'value': 'Little Women', 'languages': ['eu']},
#       {'value': 'נשים קטנות', 'languages': ['he']},
#       {'value': 'लिटिल वोमन', 'languages': ['hi']},
#       {'value': 'Little Women', 'languages': ['pt']},
#       {'value': 'Little Women (filem 2019)', 'languages': ['ms']},
#       {'value': 'زنان کوچک', 'languages': ['fa']},
#       {'value': 'Những người phụ nữ bé nhỏ', 'languages': ['vi']},
#       {'value': 'ਛੋਟੀਆਂ ਔਰਤਾਂ', 'languages': ['pa']},
#       {'value': 'Little Women', 'languages': ['ca']},
#       {'value': 'Väikesed naised', 'languages': ['et']},
#       {'value': '작은 아씨들', 'languages': ['ko']},
#       {'value': 'Little Women', 'languages': ['gl']},
#       {'value': 'สี่ดรุณี', 'languages': ['th']},
#       {'value': 'สี่ดรุณี (ภาพยนตร์ ค.ศ. 2019)', 'languages': ['th']},
#       {'value': 'Мале жене', 'languages': ['sr']},
#       {'value': 'Маленькія жанчыны', 'languages': ['be']},
#       {'value': 'Little Women', 'languages': ['nl']},
#       {'value': 'Fiicele doctorului March', 'languages': ['ro']},
#       {'value': 'Μικρές Κυρίες', 'languages': ['el']},
#       {'value': 'Les Filles du docteur March', 'languages': ['fr']},
#       {'value': 'லிட்டில் வுமன்', 'languages': ['ta']},
#       {'value': 'สี่ดรุณี (ภาพยนตร์ พ.ศ. 2562)', 'languages': ['th']},
#       {'value': 'Mazās sievietes', 'languages': ['lv']},
#       {'value': 'Little Women', 'languages': ['vi']},
#       {'value': 'Мали жени (филм од 2019)', 'languages': ['mk']},
#       {'value': 'Piccole donne', 'languages': ['it']},
#       {'value': 'Малки жени (филм, 2019)', 'languages': ['bg']},
#       {'value': 'Little Women', 'languages': ['de']},
#       {'value': '她們', 'languages': ['zh']},
#       {'value': 'Little Women', 'languages': ['li']},
#       {'value': 'Little Women', 'languages': ['ig']},
#       {'value': 'Маленькие женщины', 'languages': ['ru']},
#       {'value': '小婦人', 'languages': ['zh']},
#       {'value': 'Little Women', 'languages': ['ga']},
#       {'value': 'لٹل ویمن (2019ء فلم)', 'languages': ['ur']},
#       {'value': 'Маленькі жінки', 'languages': ['uk']},
#       {'value': 'Little Women', 'languages': ['id']},
#       {'value': 'Malé ženy', 'languages': ['cs']},
#       {'value': 'Những người phụ nữ nhỏ bé', 'languages': ['vi']},
#       {'value': 'Kisasszonyok', 'languages': ['hu']},
#       {'value': 'Male žene (2019.)', 'languages': ['hr']},
#       {'value': 'Kucuk Kadinlar', 'languages': ['tr']},
#       {'value': 'লিটল উইমেন', 'languages': ['bn']},
#       {'value': 'Pikku naisia', 'languages': ['fi']},
#       {'value': 'Little Women', 'languages': ['fi']},
#       {'value': 'Balaca qadınlar (film, 2019)', 'languages': ['az']},
#       {'value': 'Unga kvinnor', 'languages': ['sv']},
#       {'value': 'リトル・ウィメン', 'languages': ['ja']},
#       {'value': 'Małe kobietki', 'languages': ['pl']},
#       {'value': 'Little Women', 'languages': ['es']},
#       {'value': 'Little Women', 'languages': ['uz']},
#       {'value': 'Փոքրիկ տիկիններ', 'languages': ['hy']},
#       {'value': 'Küçük Kadınlar', 'languages': ['tr']},
#       {'value': 'Little Women', 'languages': ['da']}],
#      'filming_location': 'Concord, Massachusetts, USA',
#      'production_companies': ['Regency Enterprises',
#       'DiNovi Pictures',
#       'Columbia Pictures'],
#      'release_country': ['United States'],
#      'short_descriptions': [{'value': 'Ihe nkiri 2019 nke Greta Gerwig duziri',
#        'languages': ['ig']},
#       {'value': 'סרט משנת 2019', 'languages': ['he']},
#       {'value': 'amerikansk film från 2019 regisserad av Greta Gerwig',
#        'languages': ['sv']},
#       {'value': '2019년 그레타 거윅 감독의 영화', 'languages': ['ko']},
#       {'value': '2019. aasta film, lavastanud Greta Gerwig',
#        'languages': ['et']},
#       {'value': 'Greta Gerwig’in yönettiği 2019 yapımı film',
#        'languages': ['tr']},
#       {'value': 'アメリカの映画作品', 'languages': ['ja']},
#       {'value': 'filme de 2019 dirigido por Greta Gerwig',
#        'languages': ['pt']},
#       {'value': 'Ταινία της Sony', 'languages': ['el']},
#       {'value': 'film de 2019 réalisé par Greta Gerwig', 'languages': ['fr']},
#       {'value': 'cinta de 2019 dirichita por Greta Gerwig',
#        'languages': ['an']},
#       {'value': 'film i vitit 2019 i drejtuar nga Greta Gerwig',
#        'languages': ['sq']},
#       {'value': 'Film tahun 2019 oleh Greta Gerwig', 'languages': ['id']},
#       {'value': 'американский драматический фильм 2019 года режиссёра Греты Гервиг',
#        'languages': ['ru']},
#       {'value': 'Phim điện ảnh năm 2019 của Greta Gerwig dựa trên tiểu thuyết cùng tên.',
#        'languages': ['vi']},
#       {'value': 'film van Greta Gerwig', 'languages': ['nl']},
#       {'value': 'film del 2019 diretto da Greta Gerwig', 'languages': ['it']},
#       {'value': 'فيلم أنتج عام 2019', 'languages': ['ar']},
#       {'value': 'pel·lícula de 2019 dirigida per Greta Gerwig',
#        'languages': ['ca']},
#       {'value': 'film út 2019 fan Greta Gerwig', 'languages': ['fy']},
#       {'value': 'filme de 2019 dirigit per Greta Gerwig', 'languages': ['oc']},
#       {'value': 'Film von Greta Gerwig (2019)', 'languages': ['de']},
#       {'value': 'película de 2019 dirigida por Greta Gerwig',
#        'languages': ['es']},
#       {'value': 'filme de 2019 dirixido por Greta Gerwig',
#        'languages': ['gl']},
#       {'value': '2019 film directed by Greta Gerwig', 'languages': ['en']},
#       {'value': 'film din 2019 regizat de Greta Gerwig', 'languages': ['ro']},
#       {'value': 'Greta Gerwigin ohjaama elokuva vuodelta 2019',
#        'languages': ['fi']},
#       {'value': '2019-es romantikus amerikai filmdráma', 'languages': ['hu']},
#       {'value': 'film z roku 2019', 'languages': ['cs']},
#       {'value': '২০১৯ সালে মুক্তিপ্রাপ্ত গ্রেটা গারউইগ পরিচালিত ছবি',
#        'languages': ['bn']},
#       {'value': 'ภาพยนตร์ปี ค.ศ. 2019 กำกับโดยเกรตา เกอร์วิค',
#        'languages': ['th']}],
#      'websites': ['http://www.facebook.com/LittleWomenMovie/',
#       'http://www.littlewomen.movie/']},
#     'popularity': 0.9916716763683817,
#     'tags': [{'id': 'urn:tag:keyword:media:death_aunt',
#       'name': 'death of aunt',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:cinepolis_klic',
#       'name': 'Cinépolis KLIC',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:genre:media:drama',
#       'name': 'Drama',
#       'type': 'urn:tag:genre:media'},
#      {'id': 'urn:tag:streaming_service:media:telia_play',
#       'name': 'Telia Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:period_drama',
#       'name': 'period drama',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:fetch_tv',
#       'name': 'Fetch TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:womens_rights',
#       'name': 'womens rights',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:montage',
#       'name': 'montage',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:new_years_eve',
#       'name': 'new years eve',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:telstra_tv',
#       'name': 'Telstra TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:amazon_prime_video',
#       'name': 'Amazon Prime Video',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:mother_daughter_relationship',
#       'name': 'mother daughter relationship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:hollystar',
#       'name': 'Hollystar',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:neon_tv',
#       'name': 'Neon TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:horizon',
#       'name': 'Horizon',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:filmo_tv',
#       'name': 'Filmo TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:mejane',
#       'name': 'meJane',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:paris_france',
#       'name': 'paris france',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:publisher',
#       'name': 'publisher',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:netflix_kids',
#       'name': 'Netflix Kids',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:tv_2_play',
#       'name': 'TV 2 Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:viaplay',
#       'name': 'Viaplay',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:christmas',
#       'name': 'christmas',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:maxdome_store',
#       'name': 'maxdome Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:piano',
#       'name': 'piano',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:grandfather_grandson_relationship',
#       'name': 'grandfather grandson relationship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:flashback',
#       'name': 'flashback',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:tele2_play',
#       'name': 'Tele2 Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:four_sisters',
#       'name': 'four sisters',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:youtube',
#       'name': 'YouTube',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:universcine',
#       'name': 'Universcine',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:new_york_city',
#       'name': 'new york city',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:falling_through_ice',
#       'name': 'falling through ice',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:naver_store',
#       'name': 'Naver Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:generosity',
#       'name': 'generosity',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:talking_to_camera',
#       'name': 'talking to the camera',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:sky_store',
#       'name': 'Sky Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:zee5',
#       'name': 'Zee5',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:blue_tv',
#       'name': 'blue TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:aspiring_writer',
#       'name': 'aspiring writer',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:canal_vod',
#       'name': 'Canal VOD',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:hbo_max',
#       'name': 'HBO Max',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:wavve',
#       'name': 'wavve',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:death_sister',
#       'name': 'death of sister',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:vudu',
#       'name': 'Vudu',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:magentatv',
#       'name': 'MagentaTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:amateur_theatrics',
#       'name': 'amateur theatrics',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:foxtel_now',
#       'name': 'Foxtel Now',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:ivi',
#       'name': 'Ivi',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:dancing',
#       'name': 'dancing',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:boarding_house',
#       'name': 'boarding house',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:coming_age',
#       'name': 'coming of age',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:sprained_ankle',
#       'name': 'sprained ankle',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:rai_play',
#       'name': 'Rai Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:strim',
#       'name': 'Strim',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:club_illico',
#       'name': 'Club Illico',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:dtv',
#       'name': 'dTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:writer',
#       'name': 'writer',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:binge',
#       'name': 'BINGE',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:tutor',
#       'name': 'tutor',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:christmas_tree',
#       'name': 'christmas tree',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:subjective_camera',
#       'name': 'subjective camera',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:microsoft_store',
#       'name': 'Microsoft Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:google_play_movies',
#       'name': 'Google Play Movies',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:more_tv',
#       'name': 'More TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:starz_roku_premium_channel',
#       'name': 'Starz Roku Premium Channel',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:genre:media:romance',
#       'name': 'Romance',
#       'type': 'urn:tag:genre:media'},
#      {'id': 'urn:tag:keyword:media:scarlet_fever',
#       'name': 'scarlet fever',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:wink',
#       'name': 'Wink',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:timvision',
#       'name': 'Timvision',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:writing',
#       'name': 'writing',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:death_daughter',
#       'name': 'death of daughter',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:u_next',
#       'name': 'U-NEXT',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:amazon_video',
#       'name': 'Amazon Video',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:apple_tv',
#       'name': 'Apple TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:flixfling',
#       'name': 'FlixFling',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:based_on_novel',
#       'name': 'based on novel',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:blockbuster',
#       'name': 'Blockbuster',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:claro_video',
#       'name': 'Claro video',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:netflix',
#       'name': 'Netflix',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:rakuten_tv',
#       'name': 'Rakuten TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:kinopoisk',
#       'name': 'Kinopoisk',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:redbox',
#       'name': 'Redbox',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:kpn',
#       'name': 'KPN',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:watcha',
#       'name': 'Watcha',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:american_civil_war',
#       'name': 'american civil war',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:concord_massachusetts',
#       'name': 'concord massachusetts',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:mailbox',
#       'name': 'mailbox',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:family_relationships',
#       'name': 'family relationships',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:cineplex',
#       'name': 'Cineplex',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:chili',
#       'name': 'Chili',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:aspiring_painter',
#       'name': 'aspiring painter',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:female_protagonist',
#       'name': 'female protagonist',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:netflix_basic_ads',
#       'name': 'Netflix basic with Ads',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:movistar_play',
#       'name': 'Movistar Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:sister_sister_relationship',
#       'name': 'sister sister relationship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:starz_amazon_channel',
#       'name': 'Starz Amazon Channel',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:poverty',
#       'name': 'poverty',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:amc_on_demand',
#       'name': 'AMC on Demand',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:teenage_girl',
#       'name': 'teenage girl',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:horse_carriage',
#       'name': 'horse and carriage',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:sf_anytime',
#       'name': 'SF Anytime',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:pathe_thuis',
#       'name': 'Pathé Thuis',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:shorthaired_woman',
#       'name': 'shorthaired woman',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:beer_hall',
#       'name': 'beer hall',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:aunt_niece_relationship',
#       'name': 'aunt niece relationship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:starz',
#       'name': 'Starz',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:directv',
#       'name': 'DIRECTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:rain',
#       'name': 'rain',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:wealth',
#       'name': 'wealth',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_historical_drama_films',
#       'name': '2010s Historical Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_about_mother_daughter_relationships',
#       'name': 'Films About Mother–daughter Relationships',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_english_language_films',
#       'name': '2010s English-language Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_feminist_films',
#       'name': '2010s Feminist Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_about_writers',
#       'name': 'Films About Writers',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_coming_age_drama_films',
#       'name': '2010s Coming-of-age Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_produced_denise_novi',
#       'name': 'Films Produced By Denise Di Novi',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2019_romantic_drama_films',
#       'name': '2019 Romantic Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2019_films',
#       'name': '2019 Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_paris',
#       'name': 'Films Set In Paris',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_historical_romance_films',
#       'name': 'American Historical Romance Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:greta_gerwig',
#       'name': 'Greta Gerwig',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_1861',
#       'name': 'Films Set In 1861',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_historical_drama_films',
#       'name': 'American Historical Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_about_sisters',
#       'name': 'Films About Sisters',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_directed_greta_gerwig',
#       'name': 'Films Directed By Greta Gerwig',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_shot_in_massachusetts',
#       'name': 'Films Shot In Massachusetts',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:english_language_historical_drama_films',
#       'name': 'English-language Historical Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_american_films',
#       'name': '2010s American Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_christmas_films',
#       'name': 'American Christmas Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:sony_related_lists',
#       'name': 'Sony-related Lists',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_that_won_best_costume_design_academy_award',
#       'name': 'Films That Won The Best Costume Design Academy Award',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_nonlinear_narrative_films',
#       'name': 'American Nonlinear Narrative Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:english_language_romantic_drama_films',
#       'name': 'English-language Romantic Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:columbia_pictures_films',
#       'name': 'Columbia Pictures Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_1868',
#       'name': 'Films Set In 1868',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_female_buddy_films',
#       'name': '2010s Female Buddy Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_about_marriage',
#       'name': 'Films About Marriage',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:bafta_winners_films',
#       'name': 'Bafta Winners (films)',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:coming_age_romance_films',
#       'name': 'Coming-of-age Romance Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:english_language_historical_romance_films',
#       'name': 'English-language Historical Romance Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_historical_romance_films',
#       'name': '2010s Historical Romance Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_romantic_drama_films',
#       'name': 'American Romantic Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_civil_war_films',
#       'name': 'American Civil War Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:works_based_on_little_women',
#       'name': 'Works Based On Little Women',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:regency_enterprises_films',
#       'name': 'Regency Enterprises Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_shot_in_boston',
#       'name': 'Films Shot In Boston',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_massachusetts',
#       'name': 'Films Set In Massachusetts',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_scored_alexandre_desplat',
#       'name': 'Films Scored By Alexandre Desplat',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_produced_amy_pascal',
#       'name': 'Films Produced By Amy Pascal',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:lists_accolades_film',
#       'name': 'Lists Of Accolades By Film',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_coming_age_drama_films',
#       'name': 'American Coming-of-age Drama Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_new_york_city',
#       'name': 'Films Set In New York City',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_screenplays_greta_gerwig',
#       'name': 'Films With Screenplays By Greta Gerwig',
#       'type': 'urn:tag:wikipedia_category:wikidata'}],
#     'query': {'affinity': 0.9948142732096741,
#      'measurements': {'audience_growth': 0.30308288135757505}},
#     'disambiguation': '2019, Greta Gerwig',
#     'external': {'netflix': [{'id': '81140933'}],
#      'instagram': [{'id': 'littlewomenmovie'}],
#      'wikidata': [{'id': 'q56881140'}],
#      'twitter': [{'id': 'littlewomen'}],
#      'letterboxd': [{'id': 'little-women-2019'}],
#      'facebook': [{'id': 'littlewomenofficial'}],
#      'metacritic': [{'id': 'little-women-2019',
#        'critic_rating': 91,
#        'user_rating': 7.5}],
#      'imdb': [{'id': 'tt3281548',
#        'user_rating': 7.8,
#        'user_rating_count': 262169}]}},
#    {'name': 'Booksmart',
#     'entity_id': '85C499B8-4E79-49C0-90F0-19C33C1D32D8',
#     'type': 'urn:entity',
#     'subtype': 'urn:entity:movie',
#     'properties': {'release_year': 2019,
#      'release_date': '2019-05-24',
#      'description': 'On the eve of their high-school graduation, two academic superstars and best friends realize they should have worked less and played more. Determined not to fall short of their peers, the girls try to cram four years of fun into one night.',
#      'content_rating': 'R',
#      'duration': 102,
#      'image': {'url': 'https://images.qloo.com/i/85C499B8-4E79-49C0-90F0-19C33C1D32D8-420x-auto.jpg'},
#      'akas': [{'value': 'Образование', 'languages': ['ru']},
#       {'value': 'Booksmart', 'languages': ['sv']},
#       {'value': 'Բուքսմարթ', 'languages': ['hy']},
#       {'value': 'بک سمارٹ', 'languages': ['ur']},
#       {'value': 'Зубрачките', 'languages': ['bg']},
#       {'value': 'חורשות את הלילה', 'languages': ['he']},
#       {'value': 'مثقف (فيلم)', 'languages': ['ar']},
#       {'value': 'بوک اسمارت', 'languages': ['fa']},
#       {'value': 'Штреберке', 'languages': ['sr']},
#       {'value': 'Booksmart', 'languages': ['ro']},
#       {'value': 'Booksmart', 'languages': ['de']},
#       {'value': 'Booksmart', 'languages': ['id']},
#       {'value': 'Booksmart', 'languages': ['li']},
#       {'value': 'Booksmart', 'languages': ['ms']},
#       {'value': 'Booksmart', 'languages': ['nl']},
#       {'value': 'Booksmart', 'languages': ['pt']},
#       {'value': 'Booksmart - Examen de (i)maturitate', 'languages': ['ro']},
#       {'value': 'Szkoła melanżu', 'languages': ['pl']},
#       {'value': 'Booksmart', 'languages': ['es']},
#       {'value': 'Booksmart', 'languages': ['da']},
#       {'value': 'Booksmart', 'languages': ['eu']},
#       {'value': 'Booksmart', 'languages': ['cy']},
#       {'value': '북스마트', 'languages': ['ko']},
#       {'value': 'Booksmart', 'languages': ['ca']},
#       {'value': 'Éretlenségi', 'languages': ['hu']},
#       {'value': 'Booksmart', 'languages': ['fr']},
#       {'value': 'La rivincita delle sfigate', 'languages': ['it']},
#       {'value': 'ブックスマート', 'languages': ['ja']},
#       {'value': 'Booksmart', 'languages': ['fi']},
#       {'value': 'Çoxbilmiş', 'languages': ['az']},
#       {'value': 'Šprtky to chtěj taky', 'languages': ['cs']},
#       {'value': '高材生', 'languages': ['zh']}],
#      'filming_location': 'Los Angeles, California, USA',
#      'production_companies': ['Annapurna Pictures',
#       'Gloria Sanchez Productions'],
#      'release_country': ['United States'],
#      'short_descriptions': [{'value': 'film del 2019 diretto da Olivia Wilde',
#        'languages': ['it']},
#       {'value': 'اولیویا وائلڈ کی ہدایت کاری میں بننے والی 2019 کی فلم',
#        'languages': ['ur']},
#       {'value': 'фильм 2019 года режиссёра Оливии Уайлд', 'languages': ['ru']},
#       {'value': 'film van Olivia Wilde', 'languages': ['nl']},
#       {'value': '2019-ben bemutatott amerikai film', 'languages': ['hu']},
#       {'value': '2019년 영화', 'languages': ['ko']},
#       {'value': 'американски комедиен драматичен филм', 'languages': ['bg']},
#       {'value': 'קומדיית התבגרות אמריקאית', 'languages': ['he']},
#       {'value': 'americký film', 'languages': ['cs']},
#       {'value': 'ffilm gomedi am LGBT gan Olivia Wilde a gyhoeddwyd yn 2019',
#        'languages': ['cy']},
#       {'value': '2019 film directed by Olivia Wilde', 'languages': ['en']},
#       {'value': 'film z 2019 r. w reżyserii Olivii Wilde',
#        'languages': ['pl']},
#       {'value': 'film américain de 2019 réalisé par Olivia Wilde',
#        'languages': ['fr']},
#       {'value': 'película de 2019 dirigida por Olivia Wilde',
#        'languages': ['es']},
#       {'value': 'film din 2019 de Olivia Wilde', 'languages': ['ro']},
#       {'value': 'Film von Olivia Wilde (2019)', 'languages': ['de']}],
#      'websites': ['http://www.annapurna.pictures/films/booksmart',
#       'https://www.facebook.com/BooksmartUK']},
#     'popularity': 0.9794284541282385,
#     'tags': [{'id': 'urn:tag:streaming_service:media:naver_store',
#       'name': 'Naver Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:movistar_plus',
#       'name': 'Movistar Plus',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:magenta_tv',
#       'name': 'Magenta TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:girl_wears_short_shorts',
#       'name': 'girl wears short shorts',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:high_school_graduation',
#       'name': 'high school graduation',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:magentatv',
#       'name': 'MagentaTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:kpn',
#       'name': 'KPN',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:reference_to_avril_lavigne',
#       'name': 'reference to avril lavigne',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:sexual_humor',
#       'name': 'sexual humor',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:kino_on_demand',
#       'name': 'Kino on Demand',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:female_best_friend',
#       'name': 'female best friend',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:catchplay',
#       'name': 'Catchplay',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:strawberries',
#       'name': 'strawberries',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:telia_play',
#       'name': 'Telia Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:lesbian',
#       'name': 'lesbian',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:amazon_video',
#       'name': 'Amazon Video',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:cineplex',
#       'name': 'Cineplex',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:friendship',
#       'name': 'friendship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:redbox',
#       'name': 'Redbox',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:wanted_poster',
#       'name': 'wanted poster',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:last_day_school',
#       'name': 'last day of school',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:directorial_debut',
#       'name': 'directorial debut',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:abc_iview',
#       'name': 'ABC iview',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:high_school',
#       'name': 'high school',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:youtube',
#       'name': 'YouTube',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:lesbian_crush',
#       'name': 'lesbian crush',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:showmax',
#       'name': 'ShowMax',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:blockbuster',
#       'name': 'Blockbuster',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:lyft_driver',
#       'name': 'lyft driver',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:directv',
#       'name': 'DIRECTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:yorck_on_demand',
#       'name': 'Yorck on Demand',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:vudu',
#       'name': 'Vudu',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:valedictorian',
#       'name': 'valedictorian',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:puking_on_someone',
#       'name': 'puking on someone',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:netflix_basic_ads',
#       'name': 'Netflix basic with Ads',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:hbo_max',
#       'name': 'HBO Max',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:teenage_lesbian',
#       'name': 'teenage lesbian',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:lesbian_interest',
#       'name': 'lesbian interest',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:female_protagonist',
#       'name': 'female protagonist',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:genre:media:comedy',
#       'name': 'Comedy',
#       'type': 'urn:tag:genre:media'},
#      {'id': 'urn:tag:keyword:media:gender_neutral_bathroom',
#       'name': 'gender neutral bathroom',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:coming_age',
#       'name': 'coming of age',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:skateboard',
#       'name': 'skateboard',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:filmstriben',
#       'name': 'Filmstriben',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:telstra_tv',
#       'name': 'Telstra TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:hulu',
#       'name': 'Hulu',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:sky_store',
#       'name': 'Sky Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:maxdome_store',
#       'name': 'maxdome Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:sf_anytime',
#       'name': 'SF Anytime',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:rakuten_tv',
#       'name': 'Rakuten TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:lesbian_joke',
#       'name': 'lesbian joke',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:girl_wears_shorts',
#       'name': 'girl wears shorts',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:teen_movie',
#       'name': 'teen movie',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:tivify',
#       'name': 'Tivify',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:night_on_town',
#       'name': 'night on the town',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:club_illico',
#       'name': 'Club Illico',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:hallucination',
#       'name': 'hallucination',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:feminism',
#       'name': 'feminism',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:vod_poland',
#       'name': 'VOD Poland',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:cinepolis_klic',
#       'name': 'Cinépolis KLIC',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:viaplay',
#       'name': 'Viaplay',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:filmbox',
#       'name': 'FilmBox+',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:netflix',
#       'name': 'Netflix',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:nerdy_girl',
#       'name': 'nerdy girl',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:classmate',
#       'name': 'classmate',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:house_party',
#       'name': 'house party',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:dtv',
#       'name': 'dTV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:teen_party',
#       'name': 'teen party',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:amc_on_demand',
#       'name': 'AMC on Demand',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:female_friendship',
#       'name': 'female friendship',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:reference_to_pablo_picasso',
#       'name': 'reference to pablo picasso',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:teenager',
#       'name': 'teenager',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:filmoteket',
#       'name': 'Filmoteket',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:horizon',
#       'name': 'Horizon',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:party',
#       'name': 'party',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:microsoft_store',
#       'name': 'Microsoft Store',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:wavve',
#       'name': 'wavve',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:videobuster',
#       'name': 'Videobuster',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:high_school_clique',
#       'name': 'high school clique',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:tv_2_play',
#       'name': 'TV 2 Play',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:dance_scene',
#       'name': 'dance scene',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:bbc_iplayer',
#       'name': 'BBC iPlayer',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:google_play_movies',
#       'name': 'Google Play Movies',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:drug_trip',
#       'name': 'drug trip',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:mgm_amazon_channel',
#       'name': 'MGM Amazon Channel',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:fetch_tv',
#       'name': 'Fetch TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:u_next',
#       'name': 'U-NEXT',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:one_word_title',
#       'name': 'one word title',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:best_friend',
#       'name': 'best friend',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:pizza_delivery_guy',
#       'name': 'pizza delivery guy',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:keyword:media:teenage_girl_as_protagonist',
#       'name': 'teenage girl as protagonist',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:pathe_thuis',
#       'name': 'Pathé Thuis',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:teen_comedy',
#       'name': 'teen comedy',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:spectrum_on_demand',
#       'name': 'Spectrum On Demand',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:c_more',
#       'name': 'C More',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:keyword:media:friendship_between_girls',
#       'name': 'friendship between girls',
#       'type': 'urn:tag:keyword:media'},
#      {'id': 'urn:tag:streaming_service:media:apple_tv',
#       'name': 'Apple TV',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:streaming_service:media:chili',
#       'name': 'Chili',
#       'type': 'urn:tag:streaming_service:media'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:annapurna_pictures_films',
#       'name': 'Annapurna Pictures Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:films_shot_in_los_angeles',
#       'name': 'Films Shot In Los Angeles',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_female_buddy_films',
#       'name': '2010s Female Buddy Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:english_language_independent_films',
#       'name': 'English-language Independent Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:lgbtq_related_coming_age_comedy_films',
#       'name': 'Lgbtq-related Coming-of-age Comedy Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_high_school_films',
#       'name': '2010s High School Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_teen_comedy_films',
#       'name': '2010s Teen Comedy Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2019_independent_films',
#       'name': '2019 Independent Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:2010s_buddy_comedy_films',
#       'name': '2010s Buddy Comedy Films',
#       'type': 'urn:tag:wikipedia_category:wikidata'},
#      {'id': 'urn:tag:wikipedia_category:wikidata:american_teen_comedy_films',
# ...
#        'name': 'family relationships',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:promise',
#        'name': 'promise',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:boy',
#        'name': 'boy',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:filmstriben',
#        'name': 'Filmstriben',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:singing_in_a_car',
#        'name': 'singing in a car',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_nirvana',
#        'name': 'reference to nirvana',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:yle_areena',
#        'name': 'Yle Areena',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:divorce',
#        'name': 'divorce',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_melvins',
#        'name': 'reference to melvins',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:blue_tv',
#        'name': 'blue TV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:18_year_old',
#        'name': '18 year old',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:cineasterna',
#        'name': 'Cineasterna',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:orange_vod',
#        'name': 'Orange VOD',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:bfi_player',
#        'name': 'BFI Player',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:journalist',
#        'name': 'journalist',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:mother_son_relationship',
#        'name': 'mother son relationship',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:youtube',
#        'name': 'YouTube',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:fetch_tv',
#        'name': 'Fetch TV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:hypodermic_needle',
#        'name': 'hypodermic needle',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:marijuana',
#        'name': 'marijuana',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:cinemas_a_la_demande',
#        'name': 'Cinemas a la Demande',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_new_york_times',
#        'name': 'reference to the new york times',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:crystal_meth',
#        'name': 'crystal meth',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:apple_tv',
#        'name': 'Apple TV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:genre:media:drama',
#        'name': 'Drama',
#        'type': 'urn:tag:genre:media'},
#       {'id': 'urn:tag:keyword:media:based_on_true_story',
#        'name': 'based on true story',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:child_divorce',
#        'name': 'child of divorce',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:videobuster',
#        'name': 'Videobuster',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:hbo_max',
#        'name': 'HBO Max',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:mubi',
#        'name': 'MUBI',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:movistar_play',
#        'name': 'Movistar Play',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:catchplay',
#        'name': 'Catchplay',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:magentatv',
#        'name': 'MagentaTV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:sooner',
#        'name': 'Sooner',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_john_lennon',
#        'name': 'reference to john lennon',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:amazon_video',
#        'name': 'Amazon Video',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:little_girl',
#        'name': 'little girl',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:teenage_boy',
#        'name': 'teenage boy',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:viaplay',
#        'name': 'Viaplay',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:genre:media:biography',
#        'name': 'Biography',
#        'type': 'urn:tag:genre:media'},
#       {'id': 'urn:tag:keyword:media:drug_addict',
#        'name': 'drug addict',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:drug_rehabilitation',
#        'name': 'drug rehabilitation',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:little_boy',
#        'name': 'little boy',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:father_son_relationship',
#        'name': 'father son relationship',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:stepmother_stepson_relationship',
#        'name': 'stepmother stepson relationship',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:horizon',
#        'name': 'Horizon',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:watcha',
#        'name': 'Watcha',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:anger',
#        'name': 'anger',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:cocaine',
#        'name': 'cocaine',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:viu',
#        'name': 'Viu',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:pathe_thuis',
#        'name': 'Pathé Thuis',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:telia_play',
#        'name': 'Telia Play',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:marin_county_california',
#        'name': 'marin county california',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_beatles',
#        'name': 'reference to the beatles',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:wink',
#        'name': 'Wink',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:ivi',
#        'name': 'Ivi',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:los_angeles_california',
#        'name': 'los angeles california',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_metallica',
#        'name': 'reference to metallica',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:google_play_movies',
#        'name': 'Google Play Movies',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:kino_on_demand',
#        'name': 'Kino on Demand',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:cineplex',
#        'name': 'Cineplex',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:telstra_tv',
#        'name': 'Telstra TV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:naver_store',
#        'name': 'Naver Store',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:fear',
#        'name': 'fear',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_rolling_stone_magazine',
#        'name': 'reference to rolling stone magazine',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:reference_to_john_zorn',
#        'name': 'reference to john zorn',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:rakuten_tv',
#        'name': 'Rakuten TV',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:hollystar',
#        'name': 'Hollystar',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:chili',
#        'name': 'Chili',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:sky_store',
#        'name': 'Sky Store',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:san_francisco_california',
#        'name': 'san francisco california',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:streaming_service:media:tod',
#        'name': 'TOD',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:sf_anytime',
#        'name': 'SF Anytime',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:tv_2_play',
#        'name': 'TV 2 Play',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:vod_poland',
#        'name': 'VOD Poland',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:streaming_service:media:mejane',
#        'name': 'meJane',
#        'type': 'urn:tag:streaming_service:media'},
#       {'id': 'urn:tag:keyword:media:drugs',
#        'name': 'drugs',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:keyword:media:based_on_book',
#        'name': 'based on book',
#        'type': 'urn:tag:keyword:media'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_san_francisco',
#        'name': 'Films Set In San Francisco',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_about_dysfunctional_families',
#        'name': 'Films About Dysfunctional Families',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_directed_felix_van_groeningen',
#        'name': 'Films Directed By Felix Van Groeningen',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_produced_brad_pitt',
#        'name': 'Films Produced By Brad Pitt',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:english_language_biographical_drama_films',
#        'name': 'English-language Biographical Drama Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_produced_dede_gardner',
#        'name': 'Films Produced By Dede Gardner',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:american_biographical_drama_films',
#        'name': 'American Biographical Drama Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:2010s_american_films',
#        'name': '2010s American Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_based_on_multiple_works',
#        'name': 'Films Based On Multiple Works',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_based_on_memoirs',
#        'name': 'Films Based On Memoirs',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:amazon_mgm_studios_films',
#        'name': 'Amazon Mgm Studios Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:2018_films',
#        'name': '2018 Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_produced_jeremy_kleiner',
#        'name': 'Films Produced By Jeremy Kleiner',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_set_in_los_angeles',
#        'name': 'Films Set In Los Angeles',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:biographical_films_about_writers',
#        'name': 'Biographical Films About Writers',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_shot_in_san_francisco',
#        'name': 'Films Shot In San Francisco',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:2018_biographical_drama_films',
#        'name': '2018 Biographical Drama Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_about_father_son_relationships',
#        'name': 'Films About Father–son Relationships',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_about_drugs',
#        'name': 'Films About Drugs',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_shot_in_los_angeles',
#        'name': 'Films Shot In Los Angeles',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:2010s_english_language_films',
#        'name': '2010s English-language Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:plan_b_entertainment_films',
#        'name': 'Plan B Entertainment Films',
#        'type': 'urn:tag:wikipedia_category:wikidata'},
#       {'id': 'urn:tag:wikipedia_category:wikidata:films_about_parenting',
#        'name': 'Films About Parenting',
#        'type': 'urn:tag:wikipedia_category:wikidata'}],
#      'query': {'affinity': 0.9850601552227274,
#       'measurements': {'audience_growth': 0.17794143052923464}},
#      'disambiguation': '2018, Felix van Groeningen',
#      'external': {'instagram': [{'id': 'beautifulboymovie'}],
#       'wikidata': [{'id': 'q29051576'}],
#       'twitter': [{'id': 'beautifulboymov'}],
#       'letterboxd': [{'id': 'beautiful-boy-2018'}],
#       'facebook': [{'id': 'beautifulboymovie'}],
#       'metacritic': [{'id': 'beautiful-boy-2018',
#         'critic_rating': 62,
#         'user_rating': 7.2}],
#       'rottentomatoes': [{'id': 'beautiful_boy_2018',
#         'critic_rating': '100',
#         'critic_rating_count': '1',
#         'user_rating': '77',
#         'user_rating_count': '2500'}],
#       'imdb': [{'id': 'tt1226837',
#         'user_rating': 7.4,
#         'user_rating_count': 110156}]}}]},
#   'query': {'localities': {'signal': {'entity_id': '81E61924-6CEE-4AB4-93D3-282A5C784AB8',
#      'name': 'New York',
#      'subtype': 'urn:entity:locality',
#      'location': {'lat': 40.66320611815103, 'lon': -73.93889084762313},
#      'popularity': 1,
#      'disambiguation': 'New York, New York, United States of America'}}},
#   'duration': 202},
#  'postman_url': 'https://hackathon.api.qloo.com/v2/insights?filter.type=urn:entity:movie&take=5&signal.demographics.age=25_to_29&signal.demographics.gender=female&signal.location.query=New York City',
#  'headers_needed': {'X-Api-Key': 'YOUR_API_KEY'}}

# %% [markdown]
# TV Show

# %%
tv_insights = client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="tv_show",
    limit=5
)

# %%
def display_tv_show_insights(entity):
    """Display comprehensive TV show information"""
    print(f"📺 TV SHOW: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Release information
    if 'release_year' in props:
        print(f"   📅 Started: {props['release_year']}")
    if 'release_date' in props:
        print(f"   📅 First Aired: {props['release_date']}")
    
    # Episode duration
    if 'duration' in props:
        print(f"   ⏱️ Episode Length: {props['duration']} minutes")
    
    # Rating
    if 'content_rating' in props:
        print(f"   🎭 Content Rating: {props['content_rating']}")
    
    # Description
    if 'description' in props:
        description = props['description'][:200] + "..." if len(props['description']) > 200 else props['description']
        print(f"   📝 Description: {description}")
    
    # Production details
    if 'production_companies' in props and props['production_companies']:
        companies = props['production_companies'][:3]
        print(f"   🎭 Production: {', '.join(companies)}")
    
    # Filming location
    if 'filming_location' in props:
        print(f"   🎥 Filmed in: {props['filming_location']}")
    
    # Release countries
    if 'release_country' in props and props['release_country']:
        countries = props['release_country'][:3]
        print(f"   🌍 Released in: {', '.join(countries)}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    # Websites
    if 'websites' in props and props['websites']:
        print(f"   🌐 Official Site: {props['websites'][0]}")
    
    print("   " + "="*60)



"""Display all TV show insights"""
if tv_insights['success'] and tv_insights['results'].get('entities'):
    entities = tv_insights['results']['entities']
    print(f"\n📺 TV SHOW INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_tv_show_insights(entity)
else:
    print(f"\n❌ TV SHOWS: FAILED - {tv_insights.get('error', 'Unknown error')}")
# Out:
# 📺 TV SHOW INSIGHTS (5 found):
# ================================================================================
# 📺 TV SHOW: Grey's Anatomy
#    Entity ID: FE897C5A-B117-4CE1-A016-266AFD13EDA2
#    🎯 Affinity: 0.975
#    ⭐ Popularity: 0.996
#    📉 Audience Growth: -0.41
#    📅 Started: 2005
#    📅 First Aired: 2005-03-27
#    ⏱️ Episode Length: 41 minutes
#    🎭 Content Rating: TV-14
#    📝 Description: A drama centered on the personal and professional lives of five surgical interns and their supervisors.
#    🎭 Production: The Mark Gordon Company, ABC Studios, Shondaland
#    🎥 Filmed in: Veterans Hospital - 1611 Plummer Street, North Hills, Los Angeles, California, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/FE897C5A-B117-4CE1-A016-266AFD13EDA2-420x-auto.jpg
#    🌐 Official Site: https://www.channel5.com/show/grey-s-anatomy
#    ============================================================
# 📺 TV SHOW: Orange Is the New Black
#    Entity ID: 703632A9-CE72-4B10-A308-B0DB25C37BE2
#    🎯 Affinity: 0.974
#    ⭐ Popularity: 0.998
#    📈 Audience Growth: 0.61
#    📅 Started: 2013
#    📅 First Aired: 2013-07-11
#    ⏱️ Episode Length: 60 minutes
#    🎭 Content Rating: TV-MA
#    📝 Description: Convicted of a decade-old crime of transporting drug money, ordinarily law-abiding Piper Chapman is sentenced to 18 months behind bars and quickly discovers the realities of life-changing prison time.
#    🎭 Production: Tilted Productions, Lionsgate Television
#    🎥 Filmed in: Brooklyn, New York City, New York, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/703632A9-CE72-4B10-A308-B0DB25C37BE2-420x-auto.jpg
#    🌐 Official Site: https://instagram.com/oitnb/
#    ============================================================
# 📺 TV SHOW: Dollface
#    Entity ID: A2C428D6-4EA8-496F-89D0-4F12BD7076A8
#    🎯 Affinity: 0.974
#    ⭐ Popularity: 0.881
#    📉 Audience Growth: -0.23
#    📅 Started: 2019
#    📅 First Aired: 2019-11-15
#    ⏱️ Episode Length: 29 minutes
#    🎭 Content Rating: TV-MA
#    📝 Description: After breaking up with her longtime boyfriend, a woman tries to reconnect with the friends she lost during the relationship.
#    🎭 Production: Clubhouse Pictures, ABC Signature, Clubhouse Pictures (II)
#    🎥 Filmed in: Los Angeles, California, USA
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/A2C428D6-4EA8-496F-89D0-4F12BD7076A8-420x-auto.jpg
#    🌐 Official Site: https://www.hulu.com/series/dollface-5e0e449e-6bc7-4b29-8255-bc5a5f5a9f0d
#    ============================================================
# 📺 TV SHOW: Riverdale
#    Entity ID: 2588E9B0-08F1-4CE1-A13E-BC39686A8C93
#    🎯 Affinity: 0.973
#    ⭐ Popularity: 0.992
#    📈 Audience Growth: 0.41
#    📅 Started: 2017
#    📅 First Aired: 2017-01-26
#    ⏱️ Episode Length: 45 minutes
#    🎭 Content Rating: TV-14
#    📝 Description: While navigating the troubled waters of romance, school and family, Archie and his gang become entangled in dark Riverdale mysteries.
#    🎭 Production: Archie Comics Publications, Berlanti Productions, CBS Television Studios
#    🎥 Filmed in: Vancouver, British Columbia, Canada
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/2588E9B0-08F1-4CE1-A13E-BC39686A8C93-420x-auto.jpg
#    🌐 Official Site: https://www.facebook.com/CWRiverdale/
#    ============================================================
# 📺 TV SHOW: Grown-ish
#    Entity ID: 45E057A4-5951-4E77-8F56-9D447F733160
#    🎯 Affinity: 0.973
#    ⭐ Popularity: 0.856
#    📈 Audience Growth: 0.63
#    📅 Started: 2018
#    📅 First Aired: 2018-01-03
#    ⏱️ Episode Length: 22 minutes
#    🎭 Content Rating: TV-14
#    📝 Description: A spinoff of ABC's "Black-ish," Zoey Johnson is off to college and must live outside the nest, dealing with drugs, sex, and relationships along the way.
#    🎭 Production: ABC Signature
#    🌍 Released in: United States
#    🖼️ Image: https://images.qloo.com/i/45E057A4-5951-4E77-8F56-9D447F733160-420x-auto.jpg
#    🌐 Official Site: https://freeform.go.com/shows/grown-ish
#    ============================================================

# %% [markdown]
# Podcast

# %%
podcast_insights = client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="podcast",
    limit=5
)

def display_podcast_insights(entity):
    """Display comprehensive podcast information"""
    print(f"🎧 PODCAST: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Channel/Host
    if 'channel' in props:
        print(f"   🎤 Channel: {props['channel']}")
    
    # Rating
    if 'rating' in props:
        print(f"   ⭐ Rating: {props['rating']}/5.0")
    
    # Episode count
    if 'episode_count' in props:
        print(f"   📊 Episodes: {props['episode_count']}")
    
    # Release info
    if 'release_date' in props:
        print(f"   📅 Latest Episode: {props['release_date']}")
    
    # Content rating
    if 'content_rating' in props:
        print(f"   🎭 Content Rating: {props['content_rating']}")
    
    # Description
    description = props.get('short_description', props.get('description', 'No description available'))
    if len(description) > 200:
        description = description[:200] + "..."
    print(f"   📝 Description: {description}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    print("   " + "="*60)



"""Display all podcast insights"""
if podcast_insights['success'] and podcast_insights['results'].get('entities'):
    entities = podcast_insights['results']['entities']
    print(f"\n🎧 PODCAST INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_podcast_insights(entity)
else:
    print(f"\n❌ PODCASTS: FAILED - {podcast_insights.get('error', 'Unknown error')}")
# Out:
# 🎧 PODCAST INSIGHTS (5 found):
# ================================================================================
# 🎧 PODCAST: Getting Curious with Jonathan Van Ness
#    Entity ID: ED9D4C2F-37B4-476F-B3DE-5F5EEB95E859
#    🎯 Affinity: 0.972
#    ⭐ Popularity: 0.993
#    ➡️ Audience Growth: 0.00
#    🎤 Channel: Getting Curious with Jonathan Van Ness
#    ⭐ Rating: 4.9/5.0
#    📊 Episodes: 15
#    📅 Latest Episode: 2024-07-10
#    🎭 Content Rating: Explicit
#    📝 Description: Jonathan Van Ness explores diverse topics with experts, from science to entertainment, in an engaging and curious format.
#    🖼️ Image: https://images.qloo.com/i/ED9D4C2F-37B4-476F-B3DE-5F5EEB95E859-420x-auto.jpg
#    ============================================================
# 🎧 PODCAST: Stassi
#    Entity ID: 2C14E87D-F108-41BA-93D8-50C835D29628
#    🎯 Affinity: 0.971
#    ⭐ Popularity: 0.990
#    ➡️ Audience Growth: 0.00
#    🎤 Channel: Stassi
#    ⭐ Rating: 4.4/5.0
#    📊 Episodes: 15
#    📅 Latest Episode: 2024-07-10
#    🎭 Content Rating: Explicit
#    📝 Description: Stassi Schroeder Clark shares candid stories and reflections on pop culture, relationships, and style with humor and honesty.
#    🖼️ Image: https://images.qloo.com/i/2C14E87D-F108-41BA-93D8-50C835D29628-420x-auto.jpg
#    ============================================================
# 🎧 PODCAST: Bachelor Happy Hour
#    Entity ID: 53E15CDE-8143-4E6D-9978-F5F3626B717D
#    🎯 Affinity: 0.970
#    ⭐ Popularity: 0.998
#    ➡️ Audience Growth: 0.00
#    🎤 Channel: Bachelor Happy Hour
#    ⭐ Rating: 4/5.0
#    📊 Episodes: 15
#    📅 Latest Episode: 2024-07-12
#    🎭 Content Rating: Clean
#    📝 Description: Behind-the-scenes insights and exclusive details from Bachelor Nation, hosted by Joe Amabile and Serena Pitt.
#    🖼️ Image: https://images.qloo.com/i/53E15CDE-8143-4E6D-9978-F5F3626B717D-420x-auto.jpg
#    ============================================================
# 🎧 PODCAST: The Ben and Ashley I Almost Famous Podcast
#    Entity ID: 8F9F7103-258C-493B-88B4-F6AFB753D05F
#    🎯 Affinity: 0.967
#    ⭐ Popularity: 0.970
#    ➡️ Audience Growth: 0.00
#    🎤 Channel: The Ben and Ashley I Almost Famous Podcast
#    ⭐ Rating: 3.8/5.0
#    📊 Episodes: 15
#    📅 Latest Episode: 2024-07-11
#    🎭 Content Rating: Clean
#    📝 Description: Ben Higgins and Ashley Iaconetti discuss relationships, the Bachelorette, and feature interviews with celebrities and past contestants.
#    🖼️ Image: https://images.qloo.com/i/8F9F7103-258C-493B-88B4-F6AFB753D05F-420x-auto.jpg
#    ============================================================
# 🎧 PODCAST: 2 Dope Queens
#    Entity ID: 656C8017-53E3-4754-A951-7A48CEC1179C
#    🎯 Affinity: 0.966
#    ⭐ Popularity: 0.996
#    ➡️ Audience Growth: 0.00
#    🎤 Channel: 2 Dope Queens
#    ⭐ Rating: 4.8/5.0
#    📊 Episodes: 15
#    📅 Latest Episode: 2019-10-23
#    🎭 Content Rating: Explicit
#    📝 Description: Two best friends host a live comedy show featuring diverse comedians discussing race, romance, and life in New York.
#    🖼️ Image: https://images.qloo.com/i/656C8017-53E3-4754-A951-7A48CEC1179C-420x-auto.jpg
#    ============================================================

# %%
game_insights= client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="videogame",
    limit=5
)
def display_videogame_insights(entity):
    """Display comprehensive video game information"""
    print(f"🎮 GAME: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Release information
    if 'release_year' in props:
        print(f"   📅 Release Year: {props['release_year']}")
    if 'release_date' in props:
        print(f"   📅 Release Date: {props['release_date']}")
    
    # Developer and Publisher
    if 'developer' in props:
        print(f"   👨‍💻 Developer: {props['developer']}")
    if 'publisher' in props:
        print(f"   🏢 Publisher: {props['publisher']}")
    
    # Platforms
    if 'platforms' in props:
        print(f"   🖥️ Platforms: {props['platforms']}")
    
    # Content rating
    if 'content_rating' in props:
        print(f"   🎭 Rating: {props['content_rating']}")
    
    # Franchise info
    if 'franchise' in props:
        franchise = props['franchise']
        if isinstance(franchise, dict) and 'qloo_franchise_id' in franchise:
            print(f"   🏆 Franchise ID: {franchise['qloo_franchise_id']}")
    
    # Series info
    if 'part_of_the_series' in props and props['part_of_the_series']:
        series = props['part_of_the_series'][:3]
        print(f"   📚 Series: {', '.join(series)}")
    
    # Description
    description = props.get('description', 'No description available')
    if len(description) > 200:
        description = description[:200] + "..."
    print(f"   📝 Description: {description}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    print("   " + "="*60)



"""Display all video game insights"""
if game_insights['success'] and game_insights['results'].get('entities'):
    entities = game_insights['results']['entities']
    print(f"\n🎮 VIDEOGAME INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_videogame_insights(entity)
else:
    print(f"\n❌ VIDEOGAMES: FAILED - {game_insights.get('error', 'Unknown error')}")
# Out:
# 🎮 VIDEOGAME INSIGHTS (5 found):
# ================================================================================
# 🎮 GAME: Animal Crossing: New Leaf
#    Entity ID: 3699DAFA-BCC8-4A37-98C8-0B9BE5AFD40D
#    🎯 Affinity: 0.984
#    ⭐ Popularity: 0.951
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2013
#    📅 Release Date: 2013-06-09
#    👨‍💻 Developer: Nintendo
#    🏢 Publisher: Nintendo
#    🖥️ Platforms: [3DS]
#    🎭 Rating: E
#    🏆 Franchise ID: 277
#    📚 Series: Animal Crossing
#    📝 Description: There are no points or levels, just a myriad of sights and sounds, places and activities...all ready to explore. Spend your time passing new ordinances—or going fishing. Hang out at a coffee shop or v...
#    🖼️ Image: https://images.qloo.com/i/3699DAFA-BCC8-4A37-98C8-0B9BE5AFD40D-420x-auto.jpg
#    ============================================================
# 🎮 GAME: Genshin Impact
#    Entity ID: DE584C3E-25B7-4B25-9BD8-30A12D4B686F
#    🎯 Affinity: 0.983
#    ⭐ Popularity: 0.872
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2020
#    📅 Release Date: 2020-09-28
#    👨‍💻 Developer: miHoYo
#    🏢 Publisher: miHoYo
#    🖥️ Platforms: [PlayStation 4, iOS (iPhone/iPad), PC, PlayStation 5, Nintendo Switch, Xbox Series X]
#    🎭 Rating: T
#    📝 Description: Welcome to the beautiful fantasy world of Teyvat \n\nStep into a huge open-world of adventure and mystery, where heroic quests await. As a traveller from another world, you must find your lost sibling...
#    🖼️ Image: https://images.qloo.com/i/DE584C3E-25B7-4B25-9BD8-30A12D4B686F-420x-auto.jpg
#    ============================================================
# 🎮 GAME: Minecraft
#    Entity ID: CDBDE254-71F0-4640-8D04-5373BEAE5278
#    🎯 Affinity: 0.980
#    ⭐ Popularity: 1.000
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2011
#    📅 Release Date: 2011-11-18
#    👨‍💻 Developer: Mojang AB
#    🏢 Publisher: Mojang AB
#    🖥️ Platforms: [PC, Nintendo Switch, PlayStation 5, 3DS, PlayStation 3, PlayStation 4, PlayStation Vita, Wii U, Xbox 360, Xbox One]
#    🎭 Rating: E10+
#    🏆 Franchise ID: 673
#    📚 Series: Minecraft
#    📝 Description: The game involves players creating and destroying various types of blocks in a three dimensional environment. The player takes an avatar that can destroy or create blocks, forming fantastic structures...
#    🖼️ Image: https://images.qloo.com/i/CDBDE254-71F0-4640-8D04-5373BEAE5278-420x-auto.jpg
#    ============================================================
# 🎮 GAME: Fortnite
#    Entity ID: B335BB51-7158-4C34-89D1-4F1DB7CB5C01
#    🎯 Affinity: 0.979
#    ⭐ Popularity: 0.929
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2017
#    📅 Release Date: 2017-07-21
#    👨‍💻 Developer: Epic Games
#    🏢 Publisher: Gearbox Publishing
#    🖥️ Platforms: [PC, PlayStation 4, Xbox One, iOS (iPhone/iPad), Nintendo Switch, PlayStation 5, Xbox Series X]
#    🎭 Rating: T
#    📝 Description: Epic Games next project has you building forts and stopping a zombie invasion.
#    🖼️ Image: https://images.qloo.com/i/B335BB51-7158-4C34-89D1-4F1DB7CB5C01-420x-auto.jpg
#    ============================================================
# 🎮 GAME: Overwatch
#    Entity ID: 3C8166FB-794B-4FA1-97AF-593E7745B491
#    🎯 Affinity: 0.976
#    ⭐ Popularity: 0.986
#    ➡️ Audience Growth: 0.00
#    📅 Release Year: 2016
#    📅 Release Date: 2016-05-23
#    👨‍💻 Developer: Blizzard Entertainment
#    🏢 Publisher: Blizzard Entertainment
#    🖥️ Platforms: [PC, PlayStation 4, Xbox One, Nintendo Switch]
#    🎭 Rating: T
#    🏆 Franchise ID: 476
#    📚 Series: Overwatch
#    📝 Description: Overwatch is a highly stylized team-based shooter set on earth in the near future. Every match is an intense multiplayer showdown pitting a diverse cast of soldiers, mercenaries, scientists, adventure...
#    🖼️ Image: https://images.qloo.com/i/3C8166FB-794B-4FA1-97AF-593E7745B491-420x-auto.jpg
#    ============================================================

# %%
people_insights=client.get_entity_insights(
    audience_ids=audience_ids,
    signals=signals,
    entity_type="people",
    limit=5
)
def display_people_insights(entity):
    """Display comprehensive people information"""
    print(f"👤 PERSON: {entity['name']}")
    print(f"   Entity ID: {entity['entity_id']}")
    print(f"   🎯 Affinity: {entity['query']['affinity']:.3f}")
    print(f"   ⭐ Popularity: {entity['popularity']:.3f}")
    
    # Audience Growth
    growth = entity['query'].get('measurements', {}).get('audience_growth', 0)
    growth_icon = "📈" if growth > 0 else "📉" if growth < 0 else "➡️"
    print(f"   {growth_icon} Audience Growth: {growth:.2f}")
    
    props = entity.get('properties', {})
    
    # Personal info
    if 'date_of_birth' in props:
        print(f"   🎂 Born: {props['date_of_birth']}")
    
    if 'gender' in props and props['gender']:
        gender = props['gender'][0] if isinstance(props['gender'], list) else props['gender']
        print(f"   👤 Gender: {gender}")
    
    if 'citizenship' in props and props['citizenship']:
        citizenship = props['citizenship'][0] if isinstance(props['citizenship'], list) else props['citizenship']
        print(f"   🌍 Citizenship: {citizenship}")
    
    # Professional info
    if 'instrument' in props and props['instrument']:
        instruments = props['instrument'][:3] if isinstance(props['instrument'], list) else [props['instrument']]
        print(f"   🎵 Instruments: {', '.join(instruments)}")
    
    if 'work_period_start' in props:
        print(f"   💼 Career Started: {props['work_period_start']}")
    
    # Awards
    if 'award_received' in props and props['award_received']:
        awards = props['award_received'][:3] if isinstance(props['award_received'], list) else [props['award_received']]
        print(f"   🏆 Awards: {', '.join(awards)}")
    
    # Relationships
    if 'unmarried_partner' in props and props['unmarried_partner']:
        partners = props['unmarried_partner'] if isinstance(props['unmarried_partner'], list) else [props['unmarried_partner']]
        print(f"   💕 Partner: {', '.join(partners)}")
    
    # Description
    if 'short_descriptions' in props and props['short_descriptions']:
        description = props['short_descriptions'][0]
        if isinstance(description, dict) and 'value' in description:
            print(f"   📝 Description: {description['value']}")
        elif isinstance(description, str):
            print(f"   📝 Description: {description}")
    
    # Alternative names
    if 'akas' in props and props['akas']:
        akas = [aka.get('value', str(aka)) for aka in props['akas'][:3] if aka]
        print(f"   👥 Also known as: {', '.join(akas)}")
    
    # Website
    if 'official_website' in props and props['official_website']:
        website = props['official_website'][0] if isinstance(props['official_website'], list) else props['official_website']
        print(f"   🌐 Website: {website}")
    
    # Image
    if 'image' in props and 'url' in props['image']:
        print(f"   🖼️ Image: {props['image']['url']}")
    
    print("   " + "="*60)



"""Display all people insights"""
if people_insights['success'] and people_insights['results'].get('entities'):
    entities = people_insights['results']['entities']
    print(f"\n👤 PEOPLE INSIGHTS ({len(entities)} found):")
    print("="*80)
    
    for entity in entities:
        display_people_insights(entity)
else:
    print(f"\n❌ PEOPLE: FAILED - {people_insights.get('error', 'Unknown error')}")
# Out:
# 👤 PEOPLE INSIGHTS (5 found):
# ================================================================================
# 👤 PERSON: Liam Pane
#    Entity ID: 8D14B185-0229-46EC-B024-C7B50980DBBF
#    🎯 Affinity: 0.972
#    ⭐ Popularity: 1.000
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 1993-08-29
#    👤 Gender: male
#    🌍 Citizenship: United Kingdom
#    🎵 Instruments: guitar, piano, voice
#    💼 Career Started: 2008-01-01
#    🏆 Awards: Teen Choice Awards
#    💕 Partner: Cheryl
#    📝 Description: ব্রিটিশ গায়ক
#    👥 Also known as: Liam James Payne, Liam James Payne, Liam Payne
#    🌐 Website: http://www.liampayneofficial.com/
#    🖼️ Image: https://images.qloo.com/i/8D14B185-0229-46EC-B024-C7B50980DBBF-420x-auto.jpg
#    ============================================================
# 👤 PERSON: William Moseley
#    Entity ID: 8703322C-E88E-455B-835A-1BBC3D7C6282
#    🎯 Affinity: 0.971
#    ⭐ Popularity: 0.823
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 1987-04-27
#    👤 Gender: male
#    🌍 Citizenship: United Kingdom
#    💼 Career Started: 1998-01-01
#    📝 Description: actor británico
#    👥 Also known as: William Moseley, ولیم موسلی, William Peter Moseley
#    🖼️ Image: https://images.qloo.com/i/8703322C-E88E-455B-835A-1BBC3D7C6282-420x-auto.jpg
#    ============================================================
# 👤 PERSON: Kiana Madeira
#    Entity ID: 939EF787-6E11-422F-9E3C-580DC5C5BAFB
#    🎯 Affinity: 0.971
#    ⭐ Popularity: 0.686
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 1992-11-04
#    👤 Gender: female
#    🌍 Citizenship: Canada
#    📝 Description: канадська акторка
#    👥 Also known as: Կիանա Մադեիրա, Kiana Madeira, Kiana Madeira
#    ============================================================
# 👤 PERSON: Kit Young
#    Entity ID: B04B7A8D-44AC-4A02-9E98-C21F593003D0
#    🎯 Affinity: 0.968
#    ⭐ Popularity: 0.833
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 1994-10-24
#    👤 Gender: male
#    🌍 Citizenship: United Kingdom
#    📝 Description: английский актёр
#    👥 Also known as: Kit Young, 基特·楊, Kit Young
#    🖼️ Image: https://images.qloo.com/i/B04B7A8D-44AC-4A02-9E98-C21F593003D0-420x-auto.jpg
#    ============================================================
# 👤 PERSON: Emma Chamberlain
#    Entity ID: ED28F02C-C8D8-4886-8347-1B9E7228BB42
#    🎯 Affinity: 0.968
#    ⭐ Popularity: 0.995
#    ➡️ Audience Growth: 0.00
#    🎂 Born: 2001-05-22
#    👤 Gender: female
#    🌍 Citizenship: United States of America
#    🏆 Awards: Streamy Awards, Forbes 30 Under 30, Diamond Play Button
#    💕 Partner: Role Model
#    📝 Description: אושיית רשת אמריקאית
#    👥 Also known as: 엠마 체임벌린, Emma Chamberlain, אמה צ'מברלין
#    🖼️ Image: https://images.qloo.com/i/ED28F02C-C8D8-4886-8347-1B9E7228BB42-420x-auto.jpg
#    ============================================================

# %%
def get_demographics_insights(entity_ids: List[str], signals: Optional[QlooSignals] = None) -> str:
    """
    Get demographics insights for entity IDs with optional signals.
    
    :param entity_ids: List of entity IDs to analyze demographics for
    :param signals: Optional QlooSignals object containing additional signals
    :return: Formatted string containing demographics insights
    """
    demographics_result = client.get_demographics_analysis(
        entity_ids=entity_ids,
        signals=signals,
        limit=20
    )
    
    demographics_data = demographics_result.get('results', {}).get('demographics', [])
    
    if not demographics_data:
        return "No demographics results found."
    
    # Build formatted string result
    result = [f"""Below are the demographics details for the {len(demographics_data)} entities analyzed.
You can use these insights to understand the age and gender composition of your audience."""]
    result.append("")
    
    # Process each entity's demographics
    for i, demo in enumerate(demographics_data, 1):
        entity_id = demo.get("entity_id", "Unknown")
        query_data = demo.get("query", {})
        
        # Add entity header for multiple entities
        if len(demographics_data) > 1:
            result.append(f"--- ENTITY {i} ---")
        
        # Basic entity information
        result.append(f"ENTITY ID: {entity_id}")
        
        # Extract and format age data
        age_data = query_data.get("age", {})
        if age_data:
            result.append("   AGE DEMOGRAPHICS:")
            # Sort age groups by score (highest first)
            sorted_ages = sorted(age_data.items(), key=lambda x: x[1], reverse=True)
            for age_group, score in sorted_ages:
                age_display = age_group.replace('_', ' ').title()
                score_indicator = "+" if score > 0 else ""
                result.append(f"      {age_display}: {score_indicator}{score:.3f}")
        
        # Extract and format gender data
        gender_data = query_data.get("gender", {})
        if gender_data:
            result.append("   GENDER DEMOGRAPHICS:")
            for gender, score in gender_data.items():
                score_indicator = "+" if score > 0 else ""
                result.append(f"      {gender.title()}: {score_indicator}{score:.3f}")
        
        # Determine dominant demographics
        if age_data:
            dominant_age = max(age_data.items(), key=lambda x: x[1])
            result.append(f"   Dominant Age Group: {dominant_age[0].replace('_', ' ').title()} ({dominant_age[1]:+.3f})")
        
        if gender_data:
            dominant_gender = max(gender_data.items(), key=lambda x: x[1])
            if dominant_gender[1] > 0.3:  # Significant skew
                result.append(f"   Gender Skew: {dominant_gender[0].title()} ({dominant_gender[1]:+.3f})")
            else:
                result.append("   Gender Skew: Neutral")
        
        # Add spacing between entities
        if i < len(demographics_data):
            result.append("")
    
    return "\n".join(result)


def get_heatmap_insights_report(location_query: str, entity_ids: Optional[List[str]] = None, 
                               signals: Optional[QlooSignals] = None, limit: int = 50) -> str:
    """
    Get detailed heatmap insights report for a location with optional entity IDs and signals.
    
    :param location_query: Location to analyze (e.g., "Toronto", "New York")
    :param entity_ids: Optional list of entity IDs for context
    :param signals: Optional QlooSignals object containing additional signals
    :param limit: Maximum number of location points to analyze
    :return: Formatted string containing detailed heatmap insights report
    """
    heatmap_result = client.get_heatmap_analysis(
        location_query=location_query,
        entity_ids=entity_ids,
        signals=signals,
        limit=limit
    )
    
    heatmap_data = heatmap_result.get('results', {}).get('heatmap', [])
    query_info = heatmap_result.get('raw_response', {}).get('query', {})
    
    if not heatmap_data:
        return "No heatmap results found."
    
    # Get location context
    location_info = {}
    if "localities" in query_info:
        localities = query_info["localities"].get("filter", [])
        if localities:
            location_info = localities[0]
    
    # Build formatted string result
    result = [f"""DETAILED HEATMAP ANALYSIS REPORT
Location: {location_query}
Analysis Date: {heatmap_result.get('raw_response', {}).get('duration', 'N/A')}ms processing time

This report provides comprehensive geographic insights for {len(heatmap_data)} location points.
Use this data to identify high-value areas, understand spatial patterns, and optimize location-based strategies."""]
    result.append("")
    result.append("="*80)
    result.append("")
    
    # Location context
    if location_info:
        result.append("LOCATION DETAILS:")
        result.append(f"   Primary Location: {location_info.get('name', 'Unknown')}")
        if 'disambiguation' in location_info:
            result.append(f"   Full Address: {location_info['disambiguation']}")
        if 'popularity' in location_info:
            result.append(f"   Location Popularity Score: {location_info['popularity']:.4f}")
        if 'location' in location_info:
            loc_coords = location_info['location']
            result.append(f"   Center Coordinates: {loc_coords.get('lat', 'N/A'):.6f}, {loc_coords.get('lon', 'N/A'):.6f}")
        result.append("")
    
    # Calculate comprehensive statistics
    affinities = [point.get("query", {}).get("affinity", 0) for point in heatmap_data]
    popularities = [point.get("query", {}).get("popularity", 0) for point in heatmap_data]
    affinity_ranks = [point.get("query", {}).get("affinity_rank", 0) for point in heatmap_data]
    
    result.append("STATISTICAL ANALYSIS:")
    result.append(f"   Total Data Points: {len(heatmap_data)}")
    result.append(f"   Coverage Area: Geographic heatmap coverage")
    result.append("")
    
    if affinities:
        result.append("   AFFINITY METRICS:")
        result.append(f"      Range: {min(affinities):.4f} - {max(affinities):.4f}")
        result.append(f"      Average: {sum(affinities)/len(affinities):.4f}")
        result.append(f"      High Affinity Points (>0.8): {len([a for a in affinities if a > 0.8])}")
        result.append(f"      Medium Affinity Points (0.4-0.8): {len([a for a in affinities if 0.4 <= a <= 0.8])}")
        result.append(f"      Low Affinity Points (<0.4): {len([a for a in affinities if a < 0.4])}")
        result.append("")
    
    if popularities:
        result.append("   POPULARITY METRICS:")
        result.append(f"      Range: {min(popularities):.4f} - {max(popularities):.4f}")
        result.append(f"      Average: {sum(popularities)/len(popularities):.4f}")
        result.append(f"      High Popularity Points (>0.8): {len([p for p in popularities if p > 0.8])}")
        result.append(f"      Medium Popularity Points (0.4-0.8): {len([p for p in popularities if 0.4 <= p <= 0.8])}")
        result.append(f"      Low Popularity Points (<0.4): {len([p for p in popularities if p < 0.4])}")
        result.append("")
    
    if affinity_ranks:
        result.append("   RANKING METRICS:")
        result.append(f"      Affinity Rank Range: {min(affinity_ranks):.4f} - {max(affinity_ranks):.4f}")
        result.append(f"      Average Rank: {sum(affinity_ranks)/len(affinity_ranks):.4f}")
        result.append("")
    
    # Identify different tiers of hotspots
    tier1_hotspots = []  # Excellent: Both metrics > 0.8
    tier2_hotspots = []  # Good: Combined score > 0.6
    tier3_hotspots = []  # Moderate: Combined score 0.4-0.6
    
    for point in heatmap_data:
        location = point.get("location", {})
        query = point.get("query", {})
        
        affinity = query.get("affinity", 0)
        popularity = query.get("popularity", 0)
        affinity_rank = query.get("affinity_rank", 0)
        hotspot_score = (affinity * 0.6) + (popularity * 0.4)
        
        hotspot_data = {
            "latitude": location.get("latitude"),
            "longitude": location.get("longitude"),
            "geohash": location.get("geohash"),
            "affinity": affinity,
            "popularity": popularity,
            "affinity_rank": affinity_rank,
            "hotspot_score": hotspot_score
        }
        
        if affinity > 0.8 and popularity > 0.8:
            tier1_hotspots.append(hotspot_data)
        elif hotspot_score > 0.6:
            tier2_hotspots.append(hotspot_data)
        elif hotspot_score >= 0.4:
            tier3_hotspots.append(hotspot_data)
    
    # Sort each tier by score
    tier1_hotspots = sorted(tier1_hotspots, key=lambda x: x["hotspot_score"], reverse=True)
    tier2_hotspots = sorted(tier2_hotspots, key=lambda x: x["hotspot_score"], reverse=True)
    tier3_hotspots = sorted(tier3_hotspots, key=lambda x: x["hotspot_score"], reverse=True)
    
    result.append("HOTSPOT ANALYSIS:")
    result.append("")
    
    # Tier 1 - Premium hotspots
    if tier1_hotspots:
        result.append(f"   TIER 1 - PREMIUM HOTSPOTS ({len(tier1_hotspots)} locations):")
        result.append("   High affinity (>0.8) AND high popularity (>0.8)")
        result.append("")
        for i, hotspot in enumerate(tier1_hotspots[:15], 1):
            result.append(f"      --- PREMIUM LOCATION {i} ---")
            result.append(f"      Coordinates: {hotspot['latitude']:.6f}, {hotspot['longitude']:.6f}")
            result.append(f"      Geohash: {hotspot['geohash']}")
            result.append(f"      Affinity: {hotspot['affinity']:.4f}")
            result.append(f"      Popularity: {hotspot['popularity']:.4f}")
            result.append(f"      Affinity Rank: {hotspot['affinity_rank']:.4f}")
            result.append(f"      Overall Score: {hotspot['hotspot_score']:.4f}")
            result.append("")
    
    # Tier 2 - Good hotspots
    if tier2_hotspots:
        result.append(f"   TIER 2 - GOOD HOTSPOTS ({len(tier2_hotspots)} locations):")
        result.append("   Strong combined performance (score >0.6)")
        result.append("")
        for i, hotspot in enumerate(tier2_hotspots[:10], 1):
            result.append(f"      --- GOOD LOCATION {i} ---")
            result.append(f"      Coordinates: {hotspot['latitude']:.6f}, {hotspot['longitude']:.6f}")
            result.append(f"      Geohash: {hotspot['geohash']}")
            result.append(f"      Affinity: {hotspot['affinity']:.4f}")
            result.append(f"      Popularity: {hotspot['popularity']:.4f}")
            result.append(f"      Affinity Rank: {hotspot['affinity_rank']:.4f}")
            result.append(f"      Overall Score: {hotspot['hotspot_score']:.4f}")
            result.append("")
    
    # Tier 3 - Moderate hotspots (summary only)
    if tier3_hotspots:
        result.append(f"   TIER 3 - MODERATE HOTSPOTS ({len(tier3_hotspots)} locations):")
        result.append("   Moderate performance (score 0.4-0.6)")
        result.append("   Top 3 moderate locations:")
        for i, hotspot in enumerate(tier3_hotspots[:3], 1):
            result.append(f"      {i}. {hotspot['latitude']:.6f}, {hotspot['longitude']:.6f} (Score: {hotspot['hotspot_score']:.4f})")
        result.append("")
    
    # Summary recommendations
    result.append("STRATEGIC RECOMMENDATIONS:")
    total_significant = len(tier1_hotspots) + len(tier2_hotspots)
    if tier1_hotspots:
        result.append(f"   • PRIORITY FOCUS: {len(tier1_hotspots)} premium locations identified for immediate attention")
    if tier2_hotspots:
        result.append(f"   • SECONDARY TARGETS: {len(tier2_hotspots)} good locations for expansion or optimization")
    if tier3_hotspots:
        result.append(f"   • MONITORING: {len(tier3_hotspots)} moderate locations for future consideration")
    
    coverage_percent = (total_significant / len(heatmap_data)) * 100 if heatmap_data else 0
    result.append(f"   • MARKET COVERAGE: {coverage_percent:.1f}% of analyzed area shows significant potential")
    
    result.append("")
    result.append("="*80)
    
    return "\n".join(result)



def get_heatmap_data_json(location_query: str, entity_ids: Optional[List[str]] = None, 
                         signals: Optional[QlooSignals] = None, limit: int = 50) -> dict:
    """
    Get all heatmap data points as JSON/dictionary from the heatmap API - simple version.
    
    :param client: QlooAPIClient instance (initialized with your API key)
    :param location_query: Location to analyze (e.g., "Toronto", "New York")
    :param entity_ids: Optional list of entity IDs for context
    :param signals: Optional QlooSignals object containing additional signals
    :param limit: Maximum number of location points to retrieve (max 50)
    :return: Dictionary containing heatmap data points directly from API
    """
    # Ensure limit is within API bounds (1-50)
    limit = min(max(limit, 1), 50)
    
    heatmap_result = client.get_heatmap_analysis(
        location_query=location_query,
        entity_ids=entity_ids,
        signals=signals,
        limit=limit
    )
    
    if not heatmap_result.get("success"):
        return {
            "success": False,
            "error": heatmap_result.get("error", "Heatmap analysis failed"),
            "heatmap_data": []
        }
    
    # Just return the raw heatmap data from API
    heatmap_data = heatmap_result.get('results', {}).get('heatmap', [])
    
    return {
        "success": True,
        "heatmap_data": heatmap_data,
        "total_points": len(heatmap_data),
        "location_query": location_query,
        "entity_ids_used": entity_ids or [],
        "limit_requested": limit
    }

# %%
print("=== DEMOGRAPHICS TEST ===")
demo_insights = get_demographics_insights(entity_ids=["A21D248A-7379-458E-A3BE-7B8C4B961AF6","D719B77A-E9A2-4E07-BF7B-F6ED1C9521C6"])
print(demo_insights)
# Out:
# === DEMOGRAPHICS TEST ===
# Below are the demographics details for the 2 entities analyzed.
# You can use these insights to understand the age and gender composition of your audience.
#
# --- ENTITY 1 ---
# ENTITY ID: A21D248A-7379-458E-A3BE-7B8C4B961AF6
#    AGE DEMOGRAPHICS:
#       25 To 29: +0.580
#       30 To 34: +0.450
#       24 And Younger: -0.030
#       45 To 54: -0.380
#       55 And Older: -0.500
#       35 To 44: -0.730
#    GENDER DEMOGRAPHICS:
#       Male: +0.720
#       Female: -0.720
#    Dominant Age Group: 25 To 29 (+0.580)
#    Gender Skew: Male (+0.720)
#
# --- ENTITY 2 ---
# ENTITY ID: D719B77A-E9A2-4E07-BF7B-F6ED1C9521C6
#    AGE DEMOGRAPHICS:
#       25 To 29: +0.610
#       30 To 34: +0.320
#       24 And Younger: -0.020
#       45 To 54: -0.400
#       55 And Older: -0.490
#       35 To 44: -0.690
#    GENDER DEMOGRAPHICS:
#       Male: +0.710
#       Female: -0.710
#    Dominant Age Group: 25 To 29 (+0.610)
#    Gender Skew: Male (+0.710)

# %%
# Test heatmap
print("=== HEATMAP TEST ===")
heatmap_insights = get_heatmap_insights_report(location_query="Toronto", entity_ids=["A21D248A-7379-458E-A3BE-7B8C4B961AF6","D719B77A-E9A2-4E07-BF7B-F6ED1C9521C6"])
print(heatmap_insights)
# Out:
# === HEATMAP TEST ===
# DETAILED HEATMAP ANALYSIS REPORT
# Location: Toronto
# Analysis Date: 5848ms processing time
#
# This report provides comprehensive geographic insights for 1279 location points.
# Use this data to identify high-value areas, understand spatial patterns, and optimize location-based strategies.
#
# ================================================================================
#
# LOCATION DETAILS:
#    Primary Location: Toronto
#    Full Address: Toronto, Golden Horseshoe, Ontario, Canada
#    Location Popularity Score: 0.9997
#    Center Coordinates: 43.722943, -79.388412
#
# STATISTICAL ANALYSIS:
#    Total Data Points: 1279
#    Coverage Area: Geographic heatmap coverage
#
#    AFFINITY METRICS:
#       Range: 0.0000 - 1.0000
#       Average: 0.5000
#       High Affinity Points (>0.8): 256
#       Medium Affinity Points (0.4-0.8): 511
#       Low Affinity Points (<0.4): 512
#
#    POPULARITY METRICS:
#       Range: 0.0000 - 1.0000
#       Average: 0.4920
#       High Popularity Points (>0.8): 256
#       Medium Popularity Points (0.4-0.8): 508
#       Low Popularity Points (<0.4): 515
#
#    RANKING METRICS:
#       Affinity Rank Range: 0.0300 - 0.9407
#       Average Rank: 0.2919
#
# HOTSPOT ANALYSIS:
#
#    TIER 1 - PREMIUM HOTSPOTS (212 locations):
#    High affinity (>0.8) AND high popularity (>0.8)
#
#       --- PREMIUM LOCATION 1 ---
#       Coordinates: 43.716660, -79.341200
#       Geohash: dpz8dw3
#       Affinity: 0.9992
#       Popularity: 0.9977
#       Affinity Rank: 0.9124
#       Overall Score: 0.9986
#
#       --- PREMIUM LOCATION 2 ---
#       Coordinates: 43.647995, -79.386520
#       Geohash: dpz839b
#       Affinity: 0.9961
#       Popularity: 1.0000
#       Affinity Rank: 0.8734
#       Overall Score: 0.9977
#
#       --- PREMIUM LOCATION 3 ---
#       Coordinates: 43.632890, -79.418106
#       Geohash: dpz80z1
#       Affinity: 1.0000
#       Popularity: 0.9937
#       Affinity Rank: 0.9407
#       Overall Score: 0.9975
#
#       --- PREMIUM LOCATION 4 ---
#       Coordinates: 43.642500, -79.386520
#       Geohash: dpz838b
#       Affinity: 0.9945
#       Popularity: 0.9992
#       Affinity Rank: 0.8592
#       Overall Score: 0.9964
#
#       --- PREMIUM LOCATION 5 ---
#       Coordinates: 43.652115, -79.382400
#       Geohash: dpz83de
#       Affinity: 0.9906
#       Popularity: 0.9961
#       Affinity Rank: 0.8360
#       Overall Score: 0.9928
#
#       --- PREMIUM LOCATION 6 ---
#       Coordinates: 43.616410, -79.382400
#       Geohash: dpz81s5
#       Affinity: 0.9922
#       Popularity: 0.9922
#       Affinity Rank: 0.8468
#       Overall Score: 0.9922
#
#       --- PREMIUM LOCATION 7 ---
#       Coordinates: 43.641130, -79.385150
#       Geohash: dpz8389
#       Affinity: 0.9875
#       Popularity: 0.9953
#       Affinity Rank: 0.8246
#       Overall Score: 0.9906
#
#       --- PREMIUM LOCATION 8 ---
#       Coordinates: 43.641130, -79.387890
#       Geohash: dpz832x
#       Affinity: 0.9851
#       Popularity: 0.9984
#       Affinity Rank: 0.8195
#       Overall Score: 0.9905
#
#       --- PREMIUM LOCATION 9 ---
#       Coordinates: 43.671340, -79.382400
#       Geohash: dpz83w5
#       Affinity: 0.9898
#       Popularity: 0.9914
#       Affinity Rank: 0.8345
#       Overall Score: 0.9905
#
#       --- PREMIUM LOCATION 10 ---
#       Coordinates: 43.774338, -79.245070
#       Geohash: dpz9h8z
#       Affinity: 0.9969
#       Popularity: 0.9804
#       Affinity Rank: 0.8736
#       Overall Score: 0.9903
#
#       --- PREMIUM LOCATION 11 ---
#       Coordinates: 43.641130, -79.354935
#       Geohash: dpz860x
#       Affinity: 0.9844
#       Popularity: 0.9930
#       Affinity Rank: 0.8147
#       Overall Score: 0.9878
#
#       --- PREMIUM LOCATION 12 ---
#       Coordinates: 43.652115, -79.383770
#       Geohash: dpz83dd
#       Affinity: 0.9820
#       Popularity: 0.9945
#       Affinity Rank: 0.8084
#       Overall Score: 0.9870
#
#       --- PREMIUM LOCATION 13 ---
#       Coordinates: 43.621902, -79.378280
#       Geohash: dpz81tn
#       Affinity: 0.9890
#       Popularity: 0.9828
#       Affinity Rank: 0.8341
#       Overall Score: 0.9865
#
#       --- PREMIUM LOCATION 14 ---
#       Coordinates: 43.650740, -79.359055
#       Geohash: dpz864k
#       Affinity: 0.9797
#       Popularity: 0.9969
#       Affinity Rank: 0.7948
#       Overall Score: 0.9865
#
#       --- PREMIUM LOCATION 15 ---
#       Coordinates: 43.642500, -79.408490
#       Geohash: dpz830b
#       Affinity: 0.9930
#       Popularity: 0.9679
#       Affinity Rank: 0.8477
#       Overall Score: 0.9829
#
#    TIER 2 - GOOD HOTSPOTS (298 locations):
#    Strong combined performance (score >0.6)
#
#       --- GOOD LOCATION 1 ---
#       Coordinates: 43.786697, -79.206620
#       Geohash: dpz9je5
#       Affinity: 0.9640
#       Popularity: 0.7864
#       Affinity Rank: 0.7533
#       Overall Score: 0.8930
#
#       --- GOOD LOCATION 2 ---
#       Coordinates: 43.790817, -79.194260
#       Geohash: dpz9jgu
#       Affinity: 0.9272
#       Popularity: 0.7973
#       Affinity Rank: 0.6461
#       Overall Score: 0.8753
#
#       --- GOOD LOCATION 3 ---
#       Coordinates: 43.632890, -79.419480
#       Geohash: dpz80z0
#       Affinity: 0.9030
#       Popularity: 0.7527
#       Affinity Rank: 0.6078
#       Overall Score: 0.8429
#
#       --- GOOD LOCATION 4 ---
#       Coordinates: 43.698807, -79.501880
#       Geohash: dpz2wgh
#       Affinity: 0.9022
#       Popularity: 0.7527
#       Affinity Rank: 0.6068
#       Overall Score: 0.8424
#
#       --- GOOD LOCATION 5 ---
#       Coordinates: 43.797684, -79.313736
#       Geohash: dpz95jj
#       Affinity: 0.9038
#       Popularity: 0.7426
#       Affinity Rank: 0.6079
#       Overall Score: 0.8393
#
#       --- GOOD LOCATION 6 ---
#       Coordinates: 43.642500, -79.426346
#       Geohash: dpz828g
#       Affinity: 0.7973
#       Popularity: 0.8858
#       Affinity Rank: 0.4779
#       Overall Score: 0.8327
#
#       --- GOOD LOCATION 7 ---
#       Coordinates: 43.771590, -79.284900
#       Geohash: dpz95b6
#       Affinity: 0.9069
#       Popularity: 0.7113
#       Affinity Rank: 0.6121
#       Overall Score: 0.8286
#
#       --- GOOD LOCATION 8 ---
#       Coordinates: 43.789444, -79.140700
#       Geohash: dpz9p5e
#       Affinity: 0.8748
#       Popularity: 0.7465
#       Affinity Rank: 0.5743
#       Overall Score: 0.8235
#
#       --- GOOD LOCATION 9 ---
#       Coordinates: 43.650740, -79.375534
#       Geohash: dpz83f2
#       Affinity: 0.7934
#       Popularity: 0.8654
#       Affinity Rank: 0.4750
#       Overall Score: 0.8222
#
#       --- GOOD LOCATION 10 ---
#       Coordinates: 43.649370, -79.381030
#       Geohash: dpz83dh
#       Affinity: 0.7997
#       Popularity: 0.8552
#       Affinity Rank: 0.4809
#       Overall Score: 0.8219
#
#    TIER 3 - MODERATE HOTSPOTS (253 locations):
#    Moderate performance (score 0.4-0.6)
#    Top 3 moderate locations:
#       1. 43.811417, -79.231340 (Score: 0.5987)
#       2. 43.756485, -79.511490 (Score: 0.5978)
#       3. 43.698807, -79.516980 (Score: 0.5972)
#
# STRATEGIC RECOMMENDATIONS:
#    • PRIORITY FOCUS: 212 premium locations identified for immediate attention
#    • SECONDARY TARGETS: 298 good locations for expansion or optimization
#    • MONITORING: 253 moderate locations for future consideration
#    • MARKET COVERAGE: 39.9% of analyzed area shows significant potential
#
# ================================================================================

# %%
# Test heatmap
print("=== HEATMAP DATA ===")
heatmap_data = get_heatmap_data_json(location_query="Toronto", entity_ids=["A21D248A-7379-458E-A3BE-7B8C4B961AF6","D719B77A-E9A2-4E07-BF7B-F6ED1C9521C6"])
# Access the raw heatmap points
print(heatmap_data.get("heatmap_data", []))
# Out:
# === HEATMAP DATA ===
# [{'location': {'latitude': 43.63289, 'longitude': -79.418106, 'geohash': 'dpz80z1'}, 'query': {'affinity': 1, 'affinity_rank': 0.940695034060618, 'popularity': 0.9937402190923318}}, {'location': {'latitude': 43.71666, 'longitude': -79.3412, 'geohash': 'dpz8dw3'}, 'query': {'affinity': 0.9992175273865415, 'affinity_rank': 0.912352290131807, 'popularity': 0.9976525821596244}}, {'location': {'latitude': 43.744125, 'longitude': -79.471664, 'geohash': 'dpz2ze6'}, 'query': {'affinity': 0.9984350547730829, 'affinity_rank': 0.8935323897096807, 'popularity': 0.8708920187793427}}, {'location': {'latitude': 43.740005, 'longitude': -79.422226, 'geohash': 'dpz8bdw'}, 'query': {'affinity': 0.9976525821596244, 'affinity_rank': 0.8745539631471191, 'popularity': 0.8028169014084507}}, {'location': {'latitude': 43.774338, 'longitude': -79.24507, 'geohash': 'dpz9h8z'}, 'query': {'affinity': 0.9968701095461658, 'affinity_rank': 0.8735715789675171, 'popularity': 0.9804381846635368}}, {'location': {'latitude': 43.647995, 'longitude': -79.38652, 'geohash': 'dpz839b'}, 'query': {'affinity': 0.9960876369327074, 'affinity_rank': 0.8734108871809297, 'popularity': 1}}, {'location': {'latitude': 43.6837, 'longitude': -79.592514, 'geohash': 'dpz2sb6'}, 'query': {'affinity': 0.9953051643192489, 'affinity_rank': 0.87034701038967, 'popularity': 0.9374021909233177}}, {'location': {'latitude': 43.6425, 'longitude': -79.38652, 'geohash': 'dpz838b'}, 'query': {'affinity': 0.9945226917057903, 'affinity_rank': 0.8591897843266381, 'popularity': 0.9992175273865415}}, {'location': {'latitude': 43.69606, 'longitude': -79.44969, 'geohash': 'dpz884d'}, 'query': {'affinity': 0.9937402190923318, 'affinity_rank': 0.8530481082729342, 'popularity': 0.9217527386541471}}, {'location': {'latitude': 43.6425, 'longitude': -79.40849, 'geohash': 'dpz830b'}, 'query': {'affinity': 0.9929577464788732, 'affinity_rank': 0.8476561826055451, 'popularity': 0.9679186228482003}}, {'location': {'latitude': 43.61641, 'longitude': -79.3824, 'geohash': 'dpz81s5'}, 'query': {'affinity': 0.9921752738654147, 'affinity_rank': 0.846801614076867, 'popularity': 0.9921752738654147}}, {'location': {'latitude': 43.785324, 'longitude': -79.22722, 'geohash': 'dpz9j4u'}, 'query': {'affinity': 0.9913928012519562, 'affinity_rank': 0.8441164796304983, 'popularity': 0.9014084507042254}}, {'location': {'latitude': 43.652115, 'longitude': -79.3824, 'geohash': 'dpz83de'}, 'query': {'affinity': 0.9906103286384976, 'affinity_rank': 0.8360480804611798, 'popularity': 0.9960876369327074}}, {'location': {'latitude': 43.67134, 'longitude': -79.3824, 'geohash': 'dpz83w5'}, 'query': {'affinity': 0.9898278560250391, 'affinity_rank': 0.8344868010338837, 'popularity': 0.9913928012519562}}, {'location': {'latitude': 43.621902, 'longitude': -79.37828, 'geohash': 'dpz81tn'}, 'query': {'affinity': 0.9890453834115805, 'affinity_rank': 0.8340916689683243, 'popularity': 0.9827856025039123}}, {'location': {'latitude': 43.777084, 'longitude': -79.23134, 'geohash': 'dpz9j13'}, 'query': {'affinity': 0.9882629107981221, 'affinity_rank': 0.8246871681211617, 'popularity': 0.9593114241001565}}, {'location': {'latitude': 43.64113, 'longitude': -79.38515, 'geohash': 'dpz8389'}, 'query': {'affinity': 0.9874804381846636, 'affinity_rank': 0.8245735877485199, 'popularity': 0.9953051643192489}}, {'location': {'latitude': 43.689194, 'longitude': -79.47853, 'geohash': 'dpz2x3m'}, 'query': {'affinity': 0.986697965571205, 'affinity_rank': 0.8244663787785318, 'popularity': 0.9428794992175273}}, {'location': {'latitude': 43.701553, 'longitude': -79.51973, 'geohash': 'dpz2w7x'}, 'query': {'affinity': 0.9859154929577465, 'affinity_rank': 0.8217050096753387, 'popularity': 0.8904538341158059}}, {'location': {'latitude': 43.64113, 'longitude': -79.38789, 'geohash': 'dpz832x'}, 'query': {'affinity': 0.985133020344288, 'affinity_rank': 0.819529534895594, 'popularity': 0.9984350547730829}}, {'location': {'latitude': 43.64113, 'longitude': -79.354935, 'geohash': 'd ...
